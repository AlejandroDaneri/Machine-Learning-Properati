# %%
import pandas as pd

propiedades_full=pd.read_csv("../Propiedades/properati-AR-2017-08-01-properties-sell-six_months.csv")
propiedades_full.columns
# Out:
# Index([u'id', u'created_on', u'operation', u'property_type', u'place_name',
#        u'place_with_parent_names', u'country_name', u'state_name',
#        u'geonames_id', u'lat-lon', u'lat', u'lon', u'price', u'currency',
#        u'price_aprox_local_currency', u'price_aprox_usd',
#        u'surface_total_in_m2', u'surface_covered_in_m2', u'price_usd_per_m2',
#        u'price_per_m2', u'floor', u'rooms', u'expenses', u'properati_url',
#        u'description', u'title', u'image_thumbnail'],
#       dtype='object')

# %%
properties_by_type=propiedades_full[['place_name','property_type']]

# %%
properties_by_type_and_total=properties_by_type.groupby('place_name').count().reset_index()

# %%
properties_by_type_and_total.columns=['place_name','total_properties']
properties_by_type_and_total

# %%
properties_by_type=properties_by_type.groupby('place_name').apply(lambda x: x['property_type'].value_counts()).reset_index()
properties_by_type=pd.pivot_table(properties_by_type,index=['place_name'],columns=['level_1']).reset_index()
properties_by_type

# %%
 properties_by_type.columns=['place_name','PH','apartment','house','store']

# %%
properties_by_type_and_total=pd.merge(properties_by_type,properties_by_type_and_total,on = 'place_name', how='left')

# %%
properties_by_type_and_total_mean=properties_by_type_and_total

# %%
properties_by_type_and_total_mean=properties_by_type_and_total_mean.fillna(value=0)

# %%
properties_by_type_and_total_mean['apartment_mean']=properties_by_type_and_total_mean['apartment']/properties_by_type_and_total_mean['total_properties']
properties_by_type_and_total_mean['PH_mean']=properties_by_type_and_total_mean['PH']/properties_by_type_and_total_mean['total_properties']
properties_by_type_and_total_mean['house_mean']=properties_by_type_and_total_mean['house']/properties_by_type_and_total_mean['total_properties']
properties_by_type_and_total_mean['store_mean']=properties_by_type_and_total_mean['store']/properties_by_type_and_total_mean['total_properties']

# %%
properties_by_type_and_total_mean

# %%
properties_by_usd_m2=propiedades_full[['place_name','price_usd_per_m2']].dropna().groupby('place_name').mean().reset_index()

# %%
properties_by_m2_and_type_mean=pd.merge(properties_by_usd_m2,properties_by_type_and_total_mean,on='place_name',how='left')

# %%
properties_by_m2_and_type_mean.sort_values(by='price_usd_per_m2',ascending=False)\
[properties_by_m2_and_type_mean['total_properties']>20]

# %%
properties_by_type_and_total[properties_by_type_and_total['apartment_mean']<0.5].count()

# %% [markdown]
# ## propiedades con patio y a estrenar

# %%
news_properties_with_garden=pd.DataFrame({'id':propiedades_full['id'],'place_name':propiedades_full['place_name']\
                                          ,'description':propiedades_full['description'],'price_usd_per_m2':propiedades_full['price_usd_per_m2']})

# %%
news_properties_with_garden=news_properties_with_garden.dropna(how='any')

# %%
news_properties_with_garden['has_garden']=news_properties_with_garden.loc[:,'description'].str.lower().str.contains('patio')
news_properties_with_garden['is_new']=news_properties_with_garden.loc[:,'description'].str.lower().str.contains('estrenar')

# %%
news_properties_with_garden.sort_values(by='price_usd_per_m2',ascending=False)[:10]
# Out:
#                                               description  \
# 26637   Departamento  1 ambiente divisible Depto en CU...
# 26037   lan840- DEPTO FINANCIACION DIRECTA EN PESOSAnt...
# 26193   fac030- Depto anticipo en 10 meses y saldo en ...
# 114131  CODIGO:  ubicado en: MONSEÑOR TERRERO , Ituzai...
# 25853   bf221- INCREIBLE FORMA DE PAGO- ANT Y CUOTAS D...
# 44906   1119-AE035 Rosario: Av. Francia 735 (Entre Crd...
# 27066   EDIFICIO: GALA XVIII Venta en Cuotas y en Peso...
# 26992   EDIFICIO: GALA XVIII Venta en Cuotas y en Peso...
# 27004   EDIFICIO: GALA XVIII Venta en Cuotas y en Peso...
# 27065   EDIFICIO: GALA XVIII Venta en Cuotas y en Peso...
#
#                                               id       place_name  \
# 26637   59e40c3d85b8f741ecb5cb44b14d5e125ff2cf1c            Boedo
# 26037   95c4cd425c59753f4c22f544cc24f773da8f1d30            Boedo
# 26193   6be02ca3d471f5c7f0727cfc75e1bf1adaad1d2f            Boedo
# 114131  0839029ac05a47e8a05de7e3c52fb0c09d687197        Ituzaingó
# 25853   f4e58d0d84472d6bc59f6e4361fe0c936c08fc24            Boedo
# 44906   9d123e98bf8057a3fb07c13158134dce9468d29b          Rosario
# 27066   d87a267d8150bf0c2738b05d5d3e34838b5ec866  Villa Ballester
# 26992   579856cae895d7e1a307df4127162d3a60dbff8c  Villa Ballester
# 27004   a0e20cbd5c24c9c662ab3d382dc9f67ca052468a  Villa Ballester
# 27065   52effce91f223884823b62d97f0adc864e9562d9  Villa Ballester
#
#         price_usd_per_m2  has_garden  is_new
# 26637      206333.333333       False   False
# 26037      173826.066667       False   False
# 26193      104486.114286       False   False
# 114131      80000.000000        True   False
# 25853       78533.333333       False   False
# 44906       57382.080000       False   False
# 27066       48296.222222       False   False
# 26992       48296.222222       False   False
# 27004       48296.222222       False   False
# 27065       45640.000000       False   False

# %% [markdown]
# ## Veamos cuales son las ciudades que vendieron más casas con patio

# %%
properties_total=propiedades_full[['place_name','property_type']]
#Calculo el total de las ventas por ciudad
properties_total=properties_total.groupby('place_name').count().reset_index()

# %%
properties_total.columns=['place_name','total']

# %%
#Calculo la cantidad de casas con jardines vendidas por ciudad
properties_garden_count=news_properties_with_garden[['place_name','has_garden']].groupby('place_name').count().reset_index()

# %%
#Merge entre cantidad de casas con jardines con cantidad total de casas
properties_garden_count=pd.merge(properties_garden_count,properties_total,on='place_name',how='left')

# %%
properties_garden_count['has_garden_percent']=properties_garden_count['has_garden']/properties_garden_count['total']

# %%
#Elimino los datos con menores a 50 ventas.
properties_garden_count=properties_garden_count[properties_garden_count['total']>50]

# %%
properties_garden_count.sort_values(by='has_garden_percent',ascending=False)
# Out:
#                        place_name  has_garden  total  has_garden_percent
# 85              Barrio Los Alisos         268    278            0.964029
# 661                     San Roque         147    155            0.948387
# 666  Santa Barbara Barrio Cerrado          88     93            0.946237
# 770                  Villa Madero          51     54            0.944444
# 101            Barrio San Gabriel          79     87            0.908046
# 283              Fincas de Iraola          59     65            0.907692
# 80              Barrio La Alameda          56     62            0.903226
# 128                         Boedo         800    890            0.898876
# 528             Parque Centenario          61     68            0.897059
# 777                 Villa Ortuzar          77     86            0.895349
# 402                   Las Cañitas         128    143            0.895105
# 688                    Sáenz Peña          68     76            0.894737
# 216               Costa Esmeralda         111    126            0.880952
# 531                 Parque Leloir          50     57            0.877193
# 273           Estancias del Pilar          55     63            0.873016
# 110              BarrioPortezuelo          47     54            0.870370
# 171          Centro / Microcentro         193    223            0.865471
# 115                     Benavidez         522    604            0.864238
# 602             Rincón de Milberg         168    198            0.848485
# 555                   Plaza Colón          44     52            0.846154
# 786                    Villa Rosa          81     96            0.843750
# 523             Palermo Hollywood         446    532            0.838346
# 44                       Barracas         355    425            0.835294
# 727               Valeria del Mar          44     53            0.830189
# 475                     Mburucuyá          48     58            0.827586
# 328                        Güemes          75     91            0.824176
# 663                     San Telmo        1000   1216            0.822368
# 308            General Pueyrredón          66     81            0.814815
# 313                          Glew          81    100            0.810000
# 629                  San Bernardo         100    124            0.806452
# ..                            ...         ...    ...                 ...
# 450               Manuel B Gonnet          60    202            0.297030
# 575                       Punilla         210    713            0.294530
# 481                         Merlo         115    398            0.288945
# 526                        Paraná          41    144            0.284722
# 631       San Carlos de Bariloche         178    639            0.278560
# 706                        Tolosa          15     57            0.263158
# 723                       Turdera          17     69            0.246377
# 668                      Santa Fe         149    628            0.237261
# 139                       Burzaco          81    368            0.220109
# 621                         Salta          52    242            0.214876
# 754                   Villa Elisa          29    140            0.207143
# 185                     City Bell          64    317            0.201893
# 478                    Mendiolaza          15     81            0.185185
# 413                     Llavallol          27    147            0.183673
# 757        Villa General Belgrano          17    107            0.158879
# 204                   Confluencia          36    231            0.155844
# 739                 Villa Allende          32    211            0.151659
# 763            Villa La Angostura          20    134            0.149254
# 300                         Garín          22    166            0.132530
# 198                         Colón          15    117            0.128205
# 809                   Yerba Buena          22    191            0.115183
# 367                     La Calera          14    125            0.112000
# 309                  General Roca          10    108            0.092593
# 315                    Godoy Cruz           5     58            0.086207
# 672                    Santa Rosa           7     82            0.085366
# 443                         Lácar           5     60            0.083333
# 677                    Santo Tomé           6     90            0.066667
# 306                  General Pico           3     64            0.046875
# 208                       Coronda           1     57            0.017544
# 585                       Rafaela           1     68            0.014706
#
# [235 rows x 4 columns]
