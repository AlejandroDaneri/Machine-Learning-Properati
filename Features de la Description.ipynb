# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
properati = pd.read_csv('datos/properati_final.csv')
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:97% !important; }</style>"))
# Out:
# <style>.container { width:97% !important; }</style>

# %%
from sklearn.feature_extraction.text import CountVectorizer
properati.dropna(subset=["description"],inplace=True)
properati.info()

contador = CountVectorizer()
contador.fit(properati["description"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136352 entries, 0 to 136355
# Data columns (total 23 columns):
# created_on                    136352 non-null object
# property_type                 136352 non-null object
# place_name                    136352 non-null object
# state_name                    136352 non-null object
# lat-lon                       136352 non-null object
# lat                           96342 non-null float64
# lon                           96342 non-null float64
# price                         136352 non-null float64
# currency                      136352 non-null object
# price_aprox_local_currency    136352 non-null float64
# price_aprox_usd               136352 non-null float64
# surface_total_in_m2           136352 non-null float64
# surface_covered_in_m2         136352 non-null float64
# price_usd_per_m2              136352 non-null float64
# price_per_m2                  136352 non-null float64
# floor                         14294 non-null float64
# rooms                         69630 non-null float64
# expenses                      25390 non-null float64
# properati_url                 136352 non-null object
# description                   136352 non-null object
# title                         136352 non-null object
# fecha                         136352 non-null object
# superficie_descubierta        90182 non-null float64
# dtypes: float64(13), object(10)
# memory usage: 25.0+ MB

# %% [markdown]
# ### SVD

# %%
X=contador.transform(properati["description"])

from sklearn.decomposition import TruncatedSVD
componentes=10
svd=TruncatedSVD(n_components=componentes)

X_svd=(svd.fit_transform(X))

properati["features"]= [np.split(row,componentes) for row in X_svd]

print nombres

properati[nombres]=pd.DataFrame(properati.features.values.tolist())

# %%
properati[nombres].
# Out:
#                 feature1            feature2             feature3  \
# 0        [6.64316572486]     [0.55145215481]    [-0.877988696183]
# 1        [1.10058917232]    [0.606376976761]     [0.195803536014]
# 2        [1.14610456548]    [0.459410490501]     [0.301661116928]
# 3        [1.08127278369]    [0.648997417287]     [0.160220822806]
# 4        [3.34828715438]    [-1.63941421461]     [0.177562965941]
# 5        [4.50553490175]    [-1.86665282203]     [-0.12619828481]
# 6        [5.42285329395]    [0.713596257775]    [-0.558816979044]
# 7        [3.17287977198]    [-1.94885322437]     [0.104723662402]
# 8        [1.94756892259]    [0.515299429899]    [-0.244958035865]
# 9        [8.92951254013]  [-0.0945682235357]     [-2.27274204078]
# 10       [1.52924266077]   [-0.147554376428]     [0.390546385656]
# 11       [3.46051696273]    [0.314853214237]    [-0.226641744438]
# 12       [4.35782108679]    [-1.22405117974]     [0.440716378431]
# 13       [3.98256735317]    [0.105476468231]    [-0.879195162459]
# 14       [9.02403880591]  [-0.0951791298591]      [-2.0980168261]
# 15       [7.50210526013]    [0.970471940956]     [-1.67081723297]
# 16       [10.1565117152]    [-2.23447282164]  [-0.00822907685011]
# 17       [10.1163427552]    [-2.16171716124]   [-0.0039241398436]
# 18       [2.76276849576]   [-0.288632630649]     [0.120597613718]
# 19       [16.4730637947]     [2.07178111495]     [-2.39080529501]
# 20        [15.862156337]     [2.73488141394]     [-2.88669360323]
# 21       [7.37077080163]    [-6.47563435597]     [0.888890629448]
# 22       [5.62928941932]     [-1.4020129812]     [0.304598408743]
# 23       [8.82249027043]    [-6.71663292628]      [1.60293688967]
# 24      [0.210992384127]   [-0.294813734882]     [0.189375550598]
# 25        [5.9218170925]   [-0.340313924758]     [-0.41989674749]
# 26       [2.90539587737]   [-0.643532583509]     [0.249541808074]
# 27       [1.42136505836]   [-0.458223338759]    [-0.173185361827]
# 28       [49.3272396387]     [2.67262437747]     [-8.10390668903]
# 29       [15.8139035724]    [-3.11338919512]      [4.58171331265]
# ...                  ...                 ...                  ...
# 136326  [0.166189259007]    [-0.19717111546]    [0.0545255453536]
# 136327  [0.166189259007]    [-0.19717111546]    [0.0545255453536]
# 136328   [20.8763196715]    [0.843193435762]      [2.04925880784]
# 136329   [13.2016372263]     [3.13633071156]      [1.35056469963]
# 136330   [9.70518319038]    [-2.72453844311]     [0.267859225471]
# 136331   [9.70518319038]    [-2.72453844311]     [0.267859225471]
# 136332   [9.70518319038]    [-2.72453844311]     [0.267859225471]
# 136333   [9.70518319038]    [-2.72453844311]     [0.267859225471]
# 136334    [5.7498523643]    [-1.45895084936]     [0.385256231115]
# 136335   [9.70518319038]    [-2.72453844311]     [0.267859225471]
# 136336   [9.70518319038]    [-2.72453844311]     [0.267859225471]
# 136337   [12.9920689974]    [-4.86522121867]     [-1.14771062184]
# 136338   [21.7080973513]     [1.13734476323]      [1.63229952676]
# 136339   [9.18654749033]    [-3.93072585168]      [1.40497097493]
# 136340   [21.3199786516]     [1.44879347959]      [1.44008516585]
# 136341   [1.97059903375]    [-1.84305279788]  [-0.00823933452398]
# 136342   [6.86644735516]    [-2.78083651176]     [-0.58253944675]
# 136343   [4.20646146742]    [-2.08063141186]      [1.15047596945]
# 136344   [21.6172880519]    [-1.49939838395]     [-5.62809157452]
# 136345    [1.0694587776]   [-0.225151904423]    [-0.131464280721]
# 136346    [4.0352720834]     [1.23970716773]    [-0.580807748663]
# 136347   [12.8832973502]      [2.4260579824]    [0.0157532238496]
# 136348   [4.47721654999]    [-1.50438988763]     [0.458075404668]
# 136349   [5.10827222557]   [-0.242472586431]    [-0.161243091193]
# 136350   [9.18654749033]    [-3.93072585168]      [1.40497097493]
# 136351   [7.80167206147]    [-5.33392316029]    [-0.417728839492]
# 136352               NaN                 NaN                  NaN
# 136353               NaN                 NaN                  NaN
# 136354               NaN                 NaN                  NaN
# 136355               NaN                 NaN                  NaN
#
#                   feature4            feature5            feature6  \
# 0        [-0.612130232959]    [-1.43126509029]    [0.708183216513]
# 1        [-0.342778150971]   [-0.828569668332]  [-0.0242368198505]
# 2        [-0.376495909582]   [-0.966496235707]    [0.167655568946]
# 3        [-0.340817821475]   [-0.754103502092]  [-0.0802883165116]
# 4        [-0.025221312116]     [-1.7176235138]    [0.244043478046]
# 5       [-0.0777876039441]     [-2.7192143556]    [0.336686778683]
# 6         [0.703644096683]    [-2.45161346775]      [1.2041937322]
# 7         [-1.00533541376]    [-2.15032381901]   [0.0426875081944]
# 8        [-0.294039530229]   [-0.733349891218]    [0.505359825189]
# 9         [-2.00638640126]     [-2.6208726159]   [-0.649764274862]
# 10       [-0.488856278986]    [-2.13991993404]   [-0.521170273709]
# 11       [-0.850638648238]    [-1.11815933639]    [-0.19047707324]
# 12        [0.732535343877]    [-2.54973065106]     [1.42690019195]
# 13       [-0.624448524469]     [-2.6905717548]     [1.49046028494]
# 14        [-2.01511864061]    [-2.72747387227]   [-0.578877341413]
# 15        [-1.85341817828]     [-1.7489242078]   [-0.500582108994]
# 16       [-0.146578797423]    [-2.72823288792]    [-1.95608728749]
# 17       [-0.163278046534]    [-2.57554634745]    [-1.90687339532]
# 18        [0.550685644299]    [-1.06522416662]   [-0.129976505329]
# 19         [0.86161963279]    [-4.06212797507]     [1.08492446328]
# 20        [0.120396000295]    [-2.89314411963]     [1.45679998229]
# 21        [0.191921697519]  [-0.0134724334941]     [0.10322836845]
# 22         [1.82340762313]     [-2.2914890134]     [1.32609450509]
# 23        [0.594305044043]    [0.577529324241]    [0.502800946592]
# 24      [0.00620203003728]   [-0.618354996416]  [-0.0269527790154]
# 25         [1.96398689912]     [-1.7633763055]     [1.53971170057]
# 26        [0.474976858989]    [-1.11705749536]    [0.446740754781]
# 27       [-0.412421363337]  [-0.0228990998419]   [0.0566945232674]
# 28        [-2.61171538428]  [-0.0627004517523]     [1.30835382228]
# 29         [2.20864208479]    [0.204157777578]    [0.621106632315]
# ...                    ...                 ...                 ...
# 136326  [-0.0473082015207]   [-0.579356409672]   [-0.345486638337]
# 136327  [-0.0473082015207]   [-0.579356409672]   [-0.345486638337]
# 136328    [-1.94886810384]    [0.104258190501]    [-1.46743781053]
# 136329   [-0.905825834949]    [-3.28415968555]   [-0.171391504971]
# 136330     [3.20017206378]   [-0.942956188022]   [-0.276046179745]
# 136331     [3.20017206378]   [-0.942956188022]   [-0.276046179745]
# 136332     [3.20017206378]   [-0.942956188022]   [-0.276046179745]
# 136333     [3.20017206378]   [-0.942956188022]   [-0.276046179745]
# 136334   [-0.794083407692]   [-0.465218396287]    [0.193108039751]
# 136335     [3.20017206378]   [-0.942956188022]   [-0.276046179745]
# 136336     [3.20017206378]   [-0.942956188022]   [-0.276046179745]
# 136337   [-0.879128851264]    [-0.25588901785]     [-1.0303794875]
# 136338    [-2.01778238688]  [-0.0967929644089]    [-1.26389432822]
# 136339   [-0.585040363795]    [-2.58055345112]   [-0.713149916013]
# 136340    [-2.86276803858]    [0.215505571464]    [-1.12754552572]
# 136341   [-0.599501152946]   [-0.711430323475]   [0.0815063017008]
# 136342   [-0.947838214394]    [-2.15526568284]    [0.956066827455]
# 136343     [1.57889107237]    [-1.13131970594]    [0.297697365227]
# 136344    [-4.54185166932]  [-0.0256363481132]     [1.44551119521]
# 136345   [-0.166696883625]   [-0.895277183888]    [0.275797246522]
# 136346    [0.273484611514]    [-1.10800420271]      [1.0148938356]
# 136347    [0.620123503062]    [-4.27518539644]    [0.971073293497]
# 136348     [0.71078887899]   [-0.812001192745]    [0.870196241682]
# 136349   [-0.277128864745]    [-1.52175171347]   [-0.252924463815]
# 136350   [-0.585040363795]    [-2.58055345112]   [-0.713149916013]
# 136351   [-0.619327589395]    [-1.49700838282]    [-1.83418002928]
# 136352                 NaN                 NaN                 NaN
# 136353                 NaN                 NaN                 NaN
# 136354                 NaN                 NaN                 NaN
# 136355                 NaN                 NaN                 NaN
#
#                   feature7            feature8             feature9  \
# 0        [-0.264210896226]    [0.643781482361]    [-0.574934114601]
# 1        [0.0458450368626]    [0.418675367279]     [0.256425344955]
# 2       [-0.0969551236803]    [0.307289428923]     [0.344298440859]
# 3         [0.069768921205]    [0.397509257951]     [0.225486386123]
# 4         [0.312772052948]    [0.344626869991]     [0.986855180695]
# 5        [-0.448109438577]    [0.787827991275]     [0.593353520255]
# 6         [0.642927102533]   [-0.692864605188]      [1.26842619875]
# 7         [-0.95840069342]    [0.343982818134]     [0.391343980814]
# 8        [0.0423060384533]   [-0.499494385245]     [0.508408048174]
# 9        [-0.827838255495]     [1.09369562633]      [1.03506701425]
# 10       [-0.512352124803]  [-0.0640410478885]     [0.209475710559]
# 11       [-0.728548566862]    [0.231277018949]    [-0.708201277176]
# 12        [0.585948587073]   [-0.141933930921]      [1.88107220332]
# 13       [-0.562853700884]   [-0.561880044286]     [0.953686062093]
# 14       [-0.780714721814]     [1.21804914918]      [1.27044993814]
# 15       [-0.205250384412]    [0.468263147608]     [0.516599067694]
# 16        [-1.30954795216]    [0.808758075365]     [-1.06902451922]
# 17        [-1.13519595317]    [0.803657213156]     [-0.93245321406]
# 18        [-1.02005839113]  [-0.0143412605007]      [1.08596628148]
# 19        [-1.32453637889]    [0.862090737046]   [-0.0824216895708]
# 20       [-0.908334585336]     [1.17517129776]     [0.488531511525]
# 21        [0.263425323173]     [1.24792496498]      [1.76206782983]
# 22        [0.147589702346]    [-1.32801706093]      [2.39044235448]
# 23        [0.557635709409]    [0.186600923851]      [1.36630673203]
# 24       [-0.186137493448]   [-0.129455327844]    [0.0870742003112]
# 25       [-0.306053895698]      [-1.193245494]      [1.66026152665]
# 26       [-0.555375197363]   [-0.531274209146]      [1.63383577955]
# 27       [-0.115708709159]   [-0.195222558491]     [0.138913285177]
# 28         [-1.2291892834]    [-2.93106851647]      [2.19859873678]
# 29         [1.81012800003]    [0.358925641559]     [-1.17381256094]
# ...                    ...                 ...                  ...
# 136326   [-0.400607027298]   [0.0357643890054]    [-0.453684432666]
# 136327   [-0.400607027298]   [0.0357643890054]    [-0.453684432666]
# 136328    [-4.20846040969]    [0.435263732828]      [1.23691309447]
# 136329    [0.544957381055]     [2.81278794703]    [-0.882778001511]
# 136330     [1.09070677348]    [0.714149486278]     [0.125331918175]
# 136331     [1.09070677348]    [0.714149486278]     [0.125331918175]
# 136332     [1.09070677348]    [0.714149486278]     [0.125331918175]
# 136333     [1.09070677348]    [0.714149486278]     [0.125331918175]
# 136334   [-0.314604584581]   [-0.616364773315]  [-0.00707764759747]
# 136335     [1.09070677348]    [0.714149486278]     [0.125331918175]
# 136336     [1.09070677348]    [0.714149486278]     [0.125331918175]
# 136337   [-0.288391043995]     [1.03915833701]     [0.692412703405]
# 136338    [-4.41681340553]    [0.354257290314]      [1.24802454869]
# 136339    [0.549583756643]    [0.979792573594]    [-0.786518864134]
# 136340    [-4.63195038884]    [0.363502510747]       [1.0985501351]
# 136341   [-0.581921822665]    [0.354250269162]    [-0.142435115696]
# 136342    [-1.11808940217]    [0.685299436572]    [-0.305283367862]
# 136343   [-0.280146557671]    [-1.01653419538]    [-0.693834244408]
# 136344     [-4.4231905608]   [-0.405441359913]   [0.00214512914261]
# 136345   [-0.730145409051]    [-0.14780645466]     [-0.15790285863]
# 136346   [-0.432309781957]   [-0.249255619592]    [-0.859931402798]
# 136347     [1.33422253742]   [-0.363759782307]   [-0.0580714976019]
# 136348    [0.241330360327]   [-0.547289377809]      [1.28201639238]
# 136349   [-0.686095305862]     [1.03079058155]    [-0.263463417703]
# 136350    [0.549583756643]    [0.979792573594]    [-0.786518864134]
# 136351    [-1.11103896384]     [1.93404459796]     [-1.14898337903]
# 136352                 NaN                 NaN                  NaN
# 136353                 NaN                 NaN                  NaN
# 136354                 NaN                 NaN                  NaN
# 136355                 NaN                 NaN                  NaN
#
#                  feature10
# 0         [0.183067579238]
# 1        [-0.543643386403]
# 2        [-0.558472235109]
# 3        [-0.538775123324]
# 4        [0.0388034618954]
# 5         [0.666185891856]
# 6        [-0.841695167347]
# 7         [0.720323518079]
# 8        [-0.592055927033]
# 9        [0.0457319657414]
# 10      [-0.0316245090189]
# 11        [0.559130941383]
# 12        [0.338310755309]
# 13         [0.64056548687]
# 14      [0.00644866913735]
# 15        [0.444216006731]
# 16        [0.753484595468]
# 17        [0.559494813251]
# 18        [0.831963369527]
# 19         [2.57733590096]
# 20         [2.32424409485]
# 21        [0.877582988914]
# 22        [0.447115708861]
# 23        [-1.39696292841]
# 24       [0.0377526055352]
# 25        [0.152120897539]
# 26        [0.850301420889]
# 27      [-0.0619013058899]
# 28       [-0.725284983759]
# 29         [2.16761469831]
# ...                    ...
# 136326    [0.281710512848]
# 136327    [0.281710512848]
# 136328   [-0.100257271028]
# 136329    [-1.92803095059]
# 136330    [0.547542805626]
# 136331    [0.547542805626]
# 136332    [0.547542805626]
# 136333    [0.547542805626]
# 136334    [0.140135089864]
# 136335    [0.547542805626]
# 136336    [0.547542805626]
# 136337    [-1.70116980044]
# 136338    [-0.14748042318]
# 136339     [1.59823132342]
# 136340   [-0.583694054645]
# 136341    [0.425019654996]
# 136342    [0.319848861135]
# 136343    [0.590666253838]
# 136344    [-1.10610538732]
# 136345    [0.416390045038]
# 136346   [-0.251218466064]
# 136347     [1.37286617122]
# 136348   [-0.200171195643]
# 136349   [-0.931355118507]
# 136350     [1.59823132342]
# 136351     [2.02252511159]
# 136352                 NaN
# 136353                 NaN
# 136354                 NaN
# 136355                 NaN
#
# [136352 rows x 10 columns]

# %% [markdown]
# ### Busco features

# %%
properati = pd.read_csv('datos/properati_final.csv')
properati.dropna(subset=["description"],inplace=True)

# %%
descripcion = properati["description"]

# %%
descripcion
# Out:
# 0         VENTA DEPARTAMENTO DE 1 AMBIENTE CON PATIO EN ...
# 1         None- Estado del inmueble: EXCELENTE- Mejoras:...
# 2         Muy buen Chalet, a 2 cuadras e Hipermeracado J...
# 3         None- Estado del inmueble: REGULAR- Tiene gara...
# 4         Muy buen departamento; sobre avenida, a 6 cuad...
# 5         --Exclusivo Departamento de 3 Dormitorios--Tot...
# 6         Hermoso Chalet en excelente zona residencial, ...
# 7         Muy buen departamento al frente, amplios ambie...
# 8         Actualmente Alquilado.- Superficie cubierta su...
# 9         +++EXCLUSIVO SEMIPISO A ESTRENAR+++Dormitorio ...
# 10        LAS LOMITAS VENTA DIRECTA3 dormitoriosBañoToil...
# 11        +++ Con COCHERA +++Excelente semi piso al fren...
# 12        Excelente Chalet en 2 plantas.PB: jardin, livi...
# 13        Casa tipo americana, sobre Av. Frias a 1 cuadr...
# 14        +++EXCLUSIVO SEMIPISO A ESTRENAR+++Dormitorio ...
# 15        ---EXCLUSIVO SEMIPISO DE 1 AMBIENTE---Monoambi...
# 16        ESPECTACULAR DOS AMBIENTES DE 47M2 TOTALES EN ...
# 17        ESPECTACULAR DOS AMBIENTES DE 47M2 TOTALES EN ...
# 18        CODIGO: 1092-vta-lopez ubicado en: Vte. Lopez ...
# 19        CODIGO: 792-10235 ubicado en: Gelly y Obes al ...
# 20        CODIGO: 792-10233 ubicado en: Gelly y Obes al ...
# 21        CODIGO:  ubicado en: ROCA -  Publicado por: KA...
# 22        CODIGO:  ubicado en: CAAMAÑO -  Publicado por:...
# 23        CRISTIAN BAU Propiedades ofrece: CASA EN VENTA...
# 24        MOLINA CIUDADEX - ALPARGATASIMPACTANTE EDIFICI...
# 25        CODIGO: 1331-819 ubicado en: VICTORIA -  Publi...
# 26        CODIGO: 1434-TC-0132 ubicado en: Helguera 235 ...
# 27        LOTE DE 12 X 33 CON DOS DEPARTAMENTOS Y LUGAR ...
# 28        Simpatica en Casas de Santa Maria. Dos dormito...
# 29        CODIGO: 1317-156AU ubicado en: L. N. Alem -  P...
#                                 ...
# 136326    MONOAMBIENTE AL FRENTE - Consultar pisos dispo...
# 136327    MONOAMBIENTE AL FRENTE - Consultar pisos dispo...
# 136328    MONOAMBIENTE AL FRENTE - Consultar pisos dispo...
# 136329    MONOAMBIENTE AL FRENTE - Consultar pisos dispo...
# 136330    MONOAMBIENTE AL FRENTE - Consultar pisos dispo...
# 136331    MONOAMBIENTE AL FRENTE - Consultar pisos dispo...
# 136332    Ubicación privilegiada a metros del río y del ...
# 136333    Espectacular 3 ambientes en piso 13  con gran ...
# 136334    Departamentos Semipisos en Venta de 3 ambiente...
# 136335    Departamentos Semipisos en Venta de 3 ambiente...
# 136336    Departamentos Semipisos en Venta de 3 ambiente...
# 136337    Departamentos Semipisos en Venta de 3 ambiente...
# 136338    Excelente propiedad con ladrillo al frente.  P...
# 136339    Departamentos Semipisos en Venta de 3 ambiente...
# 136340    Departamentos Semipisos en Venta de 3 ambiente...
# 136341    Unico departamento de tres ambientes con ambos...
# 136342    Ubicación privilegiada a metros del río y del ...
# 136343    venta 3 ambientes con cochera fija y cubierta ...
# 136344    Ubicación privilegiada a metros del río y del ...
# 136345    Semipiso de 4 ambientes con dependencia y coch...
# 136346    VENTA SEMIPISO CON BAULERA EN BARRIO NORTE Muy...
# 136347    ESPECTACULAR OPORTUNIDAD!!! CASA DE 4 AMBIENTE...
# 136348    Vendo O Permuto Depto 3 Amb. C\ Cochera Y C\ 2...
# 136349    Excelentísimo monoambiente al frente. Super lu...
# 136350    Excelente LOFT! Impresionantes medidas.Muy amp...
# 136351    Excelente departamento de 2 ambientes en Paler...
# 136352    CASA EN UNA PLANTA UBICADA EN EL BARRIO CERRAD...
# 136353    ALQUILER DE DEPARTAMENTO 2 AMBIENTES, 40 mts2 ...
# 136354    venta 3 ambientes con cochera fija y cubierta ...
# 136355    VENTA DEPARTAMENTO 2 AMBIENTES EN BELGRANODepa...
# Name: description, Length: 136352, dtype: object

# %%
import re
palabras=[]
for row in descripcion:
    row =row.lower()
    row =row.split()
    for palabra in row:
        if len(palabra)<4: #saco conectores
            continue
        palabras.append(palabra)

# %%
from collections import Counter
contador = Counter(palabras)

# %%
contador.most_common(5000)
# Out:
# [('cocina', 97422),
#  ('para', 90561),
#  ('comedor', 71721),
#  ('ba\xc3\xb1o', 64830),
#  ('living', 63256),
#  ('ambientes', 59042),
#  ('departamento', 48857),
#  ('pisos', 47807),
#  ('dormitorios', 47433),
#  ('piso', 45078),
#  ('excelente', 44888),
#  ('venta', 43612),
#  ('dormitorio', 42765),
#  ('casa', 41014),
#  ('planta', 39616),
#  ('amplio', 35596),
#  ('suite', 31976),
#  ('frente', 31637),
#  ('propiedades', 31435),
#  ('edificio', 31129),
#  ('lavadero', 30732),
#  ('sobre', 30092),
#  ('completo', 29731),
#  ('gran', 28764),
#  ('medidas', 27909),
#  ('cuenta', 27723),
#  ('cochera', 27383),
#  ('vista', 25779),
#  ('salida', 25187),
#  ('terraza', 23902),
#  ('ubicado', 23810),
#  ('hall', 23465),
#  ('publicado', 23299),
#  ('cuadras', 23004),
#  ('comedor,', 22710),
#  ('principal', 22634),
#  ('entrada', 22357),
#  ('placard', 22104),
#  ('doble', 21962),
#  ('propiedad', 21539),
#  ('balc\xc3\xb3n', 20858),
#  ('barrio', 20370),
#  ('parrilla', 20267),
#  ('aire', 20063),
#  ('acceso', 19883),
#  ('todos', 19548),
#  ('patio', 19060),
#  ('muebles', 18886),
#  ('lote', 18645),
#  ('pileta', 18359),
#  ('mesada', 18029),
#  ('bajo', 17544),
#  ('unidades', 17452),
#  ('metros', 17071),
#  ('dormitorios,', 16706),
#  ('apto', 16491),
#  ('este', 16174),
#  ('zona', 16135),
#  ('tiene', 16075),
#  ('ba\xc3\x83\xc2\xb1o', 15656),
#  ('servicio', 15557),
#  ('buen', 15299),
#  ('espacio', 15004),
#  ('toilette', 14583),
#  ('completo.', 14582),
#  ('parte', 14523),
#  ('precio', 14288),
#  ('dependencia', 14133),
#  ('tipo', 14032),
#  ('cocheras', 13992),
#  ('madera', 13947),
#  ('esta', 13805),
#  ('agua', 13792),
#  ('inmueble', 13704),
#  ('vestidor', 13426),
#  ('tres', 13422),
#  ('ba\xc3\x91o', 13372),
#  ('amplia', 13015),
#  ('buena', 13008),
#  ('todo', 12868),
#  ('como', 12827),
#  ('expensas', 12669),
#  ('baja', 12416),
#  ('completo,', 12384),
#  ('propietario', 12322),
#  ('cubierta', 12104),
#  ('cocina,', 12092),
#  ('solo', 11740),
#  ('balcon', 11666),
#  ('trav\xc3\xa9s', 11655),
#  ('parrilla,', 11605),
#  ('amplios', 11287),
#  ('parque', 11244),
#  ('acondicionado', 11013),
#  ('estar', 10880),
#  ('encuentra', 10849),
#  ('piscina', 10691),
#  ('desde', 10623),
#  ('villa', 10619),
#  ('estado', 10532),
#  ('alta', 10482),
#  ('ambientes,', 10433),
#  ('calefacci\xc3\xb3n', 10386),
#  ('calidad', 10292),
#  ('cuadra', 10191),
#  ('calle', 10176),
#  ('primera', 10165),
#  ('diario', 10142),
#  ('ambiente', 10130),
#  ('entre', 10078),
#  ('por:', 10015),
#  ('ba\xc3\xb1os', 9868),
#  ('seguridad', 9850),
#  ('toilette,', 9764),
#  ('cuotas', 9643),
#  ('otro', 9619),
#  ('jard\xc3\xadn', 9609),
#  ('codigo:', 9603),
#  ('departamentos', 9603),
#  ('central', 9602),
#  ('mapaprop', 9599),
#  ('lavadero,', 9580),
#  ('integrada', 9435),
#  ('est\xc3\xa1', 9418),
#  ('centro', 9408),
#  ('aluminio', 9338),
#  ('subte', 9311),
#  ('m\xc3\xa1s', 9270),
#  ('quincho', 9269),
#  ('posee', 9122),
#  ('parrilla.', 8983),
#  ('estrenar', 8963),
#  ('caliente', 8933),
#  ('escritorio', 8854),
#  ('detalles', 8827),
#  ('valor', 8802),
#  ('totalmente', 8753),
#  ('aproximadas', 8735),
#  ('placard,', 8731),
#  ('luminoso', 8721),
#  ('acero', 8658),
#  ('null.', 8656),
#  ('marca', 8643),
#  ('superficie', 8576),
#  ('pueden', 8441),
#  ('diario,', 8409),
#  ('unidad', 8383),
#  ('fondo', 8302),
#  ('afip', 8042),
#  ('jardin', 8022),
#  ('sector', 7988),
#  ('comercial', 7855),
#  ('puede', 7785),
#  ('aberturas', 7757),
#  ('garage', 7673),
#  ('losa', 7611),
#  ('complejo', 7595),
#  ('interiores', 7472),
#  ('cada', 7421),
#  ('plantas', 7414),
#  ('cuarto', 7309),
#  ('todas', 7255),
#  ('independiente', 7237),
#  ('galer\xc3\xada', 7235),
#  ('frente,', 7175),
#  ('puertas', 7161),
#  ('ideal', 7107),
#  ('ubicaci\xc3\xb3n', 7054),
#  ('ambientes.', 7037),
#  ('sala', 7037),
#  ('primer', 7032),
#  ('escalera', 6904),
#  ('plaza', 6889),
#  ('estaci\xc3\xb3n', 6889),
#  ('hasta', 6856),
#  ('fotos', 6846),
#  ('superficies', 6752),
#  ('estilo', 6695),
#  ('chalet', 6666),
#  ('living,', 6619),
#  ('horno', 6537),
#  ('general', 6519),
#  ('supeditada', 6473),
#  ('negocios', 6442),
#  ('entrega', 6434),
#  ('puerta', 6412),
#  ('local', 6397),
#  ('monoambiente', 6292),
#  ('surgen', 6281),
#  ('servicios', 6273),
#  ('traves', 6217),
#  ('datos', 6200),
#  ('frente.', 6195),
#  ('baja:', 6190),
#  ('segundo', 6187),
#  ('lavadero.', 6176),
#  ('hacia', 6149),
#  ('titulo', 6031),
#  ('vestidor,', 6011),
#  ('porcelanato', 5984),
#  ('caldera', 5960),
#  ('solarium', 5936),
#  ('toilette.', 5935),
#  ('cubiertos', 5913),
#  ('alta:', 5851),
#  ('t\xc3\xadtulo', 5825),
#  ('sucursal', 5794),
#  ('posibilidad', 5782),
#  ('reales', 5777),
#  ('buenos', 5759),
#  ('valores', 5754),
#  ('vistas', 5723),
#  ('avenida', 5656),
#  ('otros', 5614),
#  ('sum,', 5613),
#  ('total', 5600),
#  ('c\xc3\xb3digo', 5574),
#  ('contrafrente', 5566),
#  ('capital', 5565),
#  ('cucicba', 5557),
#  ('instalaci\xc3\xb3n', 5551),
#  ('exterior', 5545),
#  ('espacios', 5518),
#  ('baulera', 5488),
#  ('suite,', 5478),
#  ('toda', 5450),
#  ('consta', 5441),
#  ('santa', 5406),
#  ('impecable', 5398),
#  ('hermoso', 5388),
#  ('duplex', 5375),
#  ('techo', 5372),
#  ('excelentes', 5328),
#  ('vidrio', 5308),
#  ('propiedades.', 5284),
#  ('completos', 5284),
#  ('nuevo', 5283),
#  ('autos', 5240),
#  ('servicio.', 5235),
#  ('importante', 5195),
#  ('cual', 5184),
#  ('lugar', 5178),
#  ('inmobiliaria', 5148),
#  ('barra', 5129),
#  ('cubierto', 5119),
#  ('medios', 5111),
#  ('radiante', 5076),
#  ('completa', 5038),
#  ('placard.', 5027),
#  ('bacha', 5018),
#  ('ba\xc3\xb1o,', 5012),
#  ('artefactos', 4933),
#  ('proyecto', 4912),
#  ('linea', 4868),
#  ('grandes', 4837),
#  ('comedor.', 4832),
#  ('mesada,', 4816),
#  ('cerca', 4809),
#  ('planos', 4798),
#  ('paredes', 4796),
#  ('sujeta', 4778),
#  ('hogar', 4771),
#  ('luminoso.', 4769),
#  ('l\xc3\xadnea', 4753),
#  ('emprendimiento', 4747),
#  ('playroom', 4746),
#  ('efecto', 4745),
#  ('palermo', 4731),
#  ('presente', 4725),
#  ('amenities', 4710),
#  ('galeria', 4708),
#  ('mismo', 4705),
#  ('split', 4696),
#  ('esquina', 4674),
#  ('escritorio,', 4637),
#  ('granito', 4626),
#  ('ba\xc3\xb1o.', 4607),
#  ('coti', 4603),
#  ('anafe', 4597),
#  ('solarium,', 4590),
#  ('color', 4559),
#  ('super', 4491),
#  ('desarrollada', 4488),
#  ('mts.', 4484),
#  ('habitaci\xc3\xb3n', 4473),
#  ('donde', 4455),
#  ('ducha', 4448),
#  ('parquet', 4422),
#  ('semi', 4419),
#  ('bien', 4387),
#  ('inmuebles', 4386),
#  ('informaci\xc3\xb3n', 4385),
#  ('2371', 4382),
#  ('libre', 4362),
#  ('cerrado', 4342),
#  ('jard\xc3\x83\xc2\xadn', 4342),
#  ('vivienda', 4340),
#  ('club', 4336),
#  ('torre', 4331),
#  ('piscina,', 4293),
#  ('tiro', 4269),
#  ('sistema', 4256),
#  ('cumplimiento', 4246),
#  ('dormitorio,', 4218),
#  ('recepci\xc3\xb3n,', 4218),
#  ('revestimiento', 4205),
#  ('mejor', 4203),
#  ('habitaciones', 4180),
#  ('equipos', 4179),
#  ('fija', 4167),
#  ('equipada', 4162),
#  ('luminoso,', 4145),
#  ('surgir\xc3\xa1n', 4132),
#  ('aviso', 4109),
#  ('aires', 4103),
#  ('pileta,', 4101),
#  ('servicio,', 4094),
#  ('renta', 4090),
#  ('entrada,', 4078),
#  ('riego', 4070),
#  ('living-comedor', 4016),
#  ('hermosa', 4010),
#  ('deck', 4006),
#  ('alto', 4002),
#  ('ventanales', 4001),
#  ('lepore', 3998),
#  ('forma', 3982),
#  ('terraza.', 3968),
#  ('depto', 3963),
#  ('amenities:', 3943),
#  ('vestidor.', 3919),
#  ('ubicada', 3916),
#  ('dise\xc3\xb1o', 3909),
#  ('ellos', 3899),
#  ('recepci\xc3\xb3n', 3899),
#  ('documentaci\xc3\xb3n', 3867),
#  ('dormitorios.', 3847),
#  ('lindo', 3847),
#  ('terreno', 3844),
#  ('expensas,', 3831),
#  ('propiedad:', 3828),
#  ('individual', 3822),
#  ('sanitarios', 3794),
#  ('placards', 3793),
#  ('ante', 3767),
#  ('independiente.', 3762),
#  ('cocina.', 3745),
#  ('integrada,', 3740),
#  ('norte', 3731),
#  ('bajas', 3717),
#  ('inmomap', 3717),
#  ('.publicado', 3717),
#  ('resoluci\xc3\xb3n', 3714),
#  ('diario.', 3714),
#  ('corrido', 3714),
#  ('balc\xc3\xb3n.', 3712),
#  ('piso,', 3699),
#  ('realizar', 3659),
#  ('placares', 3644),
#  ('independiente,', 3611),
#  ('piso:', 3607),
#  ('previo', 3601),
#  ('usos', 3592),
#  ('calefaccion', 3591),
#  ('tambi\xc3\xa9n', 3586),
#  ('grande', 3572),
#  ('balc\xc3\xb3n,', 3571),
#  ('terraza,', 3558),
#  ('juegos', 3557),
#  ('comparten', 3557),
#  ('aprox.', 3543),
#  ('medidas,', 3535),
#  ('altura', 3509),
#  ('madera,', 3500),
#  ('altos', 3497),
#  ('porcellanato', 3480),
#  ('varios', 3473),
#  ('fueron', 3465),
#  ('linda', 3456),
#  ('construcci\xc3\xb3n', 3455),
#  ('amplias', 3451),
#  ('gimnasio,', 3431),
#  ('espectacular', 3431),
#  ('interno', 3423),
#  ('gimnasio', 3419),
#  ('calefacci\xc3\x83\xc2\xb3n', 3414),
#  ('estado.', 3408),
#  ('corredor', 3403),
#  ('terminaciones', 3402),
#  ('profesional', 3400),
#  ('cualquier', 3390),
#  ('pesos', 3382),
#  ('informativo,', 3369),
#  ('cuatro', 3364),
#  ('deja', 3362),
#  ('transporte', 3345),
#  ('profesionales', 3340),
#  ('oportunidad', 3335),
#  ('propio', 3332),
#  ('inmejorable', 3322),
#  ('balcones', 3318),
#  ('propia', 3297),
#  ('oferta', 3288),
#  ('cancha', 3278),
#  ('estudio', 3275),
#  ('propietario.', 3270),
#  ('visualgestion', 3267),
#  ('ciudad', 3266),
#  ('lago', 3262),
#  ('incluye', 3262),
#  ('natural', 3245),
#  ('galer\xc3\x83\xc2\xada', 3244),
#  ('ambos', 3239),
#  ('impuestos', 3237),
#  ('requisitos', 3231),
#  ('a\xc3\xb1os', 3228),
#  ('moderno', 3225),
#  ('pisos,', 3214),
#  ('inmueble.', 3205),
#  ('puerto', 3205),
#  ('ventanas', 3199),
#  ('suite.', 3191),
#  ('categor\xc3\xada', 3182),
#  ('orientativo.', 3178),
#  ('inoxidable', 3178),
#  ('reciclado', 3171),
#  ('autos.', 3170),
#  ('profesional.', 3165),
#  ('flotante', 3153),
#  ('ascensores', 3153),
#  ('semipiso', 3151),
#  ('plantas,', 3138),
#  ('tercer', 3130),
#  ('servicios,', 3128),
#  ('credito', 3111),
#  ('sal\xc3\xb3n', 3110),
#  ('grifer\xc3\xada', 3109),
#  ('ubicacion', 3107),
#  ('constancia', 3102),
#  ('ventana', 3091),
#  ('living-comedor,', 3075),
#  ('canchas', 3059),
#  ('baulera.', 3041),
#  ('vigilancia', 3035),
#  ('tienen', 3014),
#  ('sujeto', 3013),
#  ('auto', 3010),
#  ('cercano', 3001),
#  ('abierta', 2992),
#  ('transferencia', 2979),
#  ('vende', 2973),
#  ('t\xc3\xadtulos', 2972),
#  ('pileta.', 2969),
#  ('interior', 2961),
#  ('techos', 2960),
#  ('termotanque', 2956),
#  ('distribuci\xc3\xb3n', 2947),
#  ('legal:', 2934),
#  ('hora', 2925),
#  ('ascensor', 2924),
#  ('autos,', 2919),
#  ('juan', 2913),
#  ('radiante.', 2910),
#  ('pasillo', 2907),
#  ('aviso.', 2899),
#  ('similar.', 2890),
#  ('escritorio.', 2879),
#  ('anticipo', 2856),
#  ('laundry', 2853),
#  ('grupo', 2846),
#  ('tramitaci\xc3\xb3n', 2845),
#  ('calidad.', 2840),
#  ('separada', 2831),
#  ('aproximados,', 2828),
#  ('car\xc3\xa1cter', 2828),
#  ('balc\xc3\x83\xc2\xb3n', 2824),
#  ('estacion', 2823),
#  ('cubiertas', 2813),
#  ('palier', 2811),
#  ('dependencias', 2804),
#  ('m\xc3\xa1rmol', 2804),
#  ('patio,', 2804),
#  ('l\xc3\xadneas', 2801),
#  ('matr\xc3\xadcula', 2797),
#  ('ba\xc3\xb1era', 2785),
#  ('family', 2785),
#  ('hace', 2785),
#  ('cmcpsi', 2779),
#  ('completos,', 2779),
#  ('balc\xc3\x93n', 2774),
#  ('corrientes', 2772),
#  ('discordancias', 2764),
#  ('portero', 2764),
#  ('deber\xc3\xa1', 2762),
#  ('bano', 2761),
#  ('madera.', 2757),
#  ('dormitorio.', 2738),
#  ('laundry,', 2726),
#  ('descripciones', 2717),
#  ('funcionales,', 2713),
#  ('aproximados.', 2712),
#  ('contra', 2705),
#  ('actualizados', 2702),
#  ('hogar,', 2702),
#  ('mesadas', 2694),
#  ('mueble', 2681),
#  ('yeso', 2680),
#  ('otra', 2670),
#  ('respectivas', 2665),
#  ('proporcionados', 2664),
#  ('legales', 2661),
#  ('accede', 2656),
#  ('arrojar', 2656),
#  ('inexactitudes', 2654),
#  ('totales', 2647),
#  ('ingreso', 2644),
#  ('visualizaci\xc3\xb3n', 2638),
#  ('plantas.', 2638),
#  ('est\xc3\xa1n', 2633),
#  ('estado,', 2627),
#  ('previamente', 2625),
#  ('central.', 2616),
#  ('obra', 2616),
#  ('pago', 2614),
#  ('amb.', 2612),
#  ('ser\xc3\xa1n', 2612),
#  ('inmobiliarios', 2611),
#  ('arquitect\xc3\xb3nicas', 2604),
#  ('realizaci\xc3\xb3n', 2603),
#  ('dentro', 2601),
#  ('interesado', 2589),
#  ('alacenas', 2588),
#  ('necesarias', 2586),
#  ('facturas,', 2583),
#  ('baja,', 2582),
#  ('residencial', 2575),
#  ('operaci\xc3\xb3n,', 2574),
#  ('copias', 2568),
#  ('recepci\xc3\xb3n.', 2567),
#  ('amplio,', 2566),
#  ('requiriendo', 2565),
#  ('verificaciones', 2563),
#  ('revestida', 2559),
#  ('tren', 2555),
#  ('conexi\xc3\xb3n', 2544),
#  ('adem\xc3\xa1s', 2543),
#  ('caballito', 2538),
#  ('medio', 2535),
#  ('contrafrente.', 2534),
#  ('guarda', 2525),
#  ('izrastzoff:', 2504),
#  ('piso.', 2497),
#  ('panamericana', 2493),
#  ('pues', 2486),
#  ('nivel', 2482),
#  ('contar\xc3\xa1', 2472),
#  ('el\xc3\xa9ctrico', 2462),
#  ('igual', 2457),
#  ('sujetos', 2455),
#  ('lineas', 2449),
#  ('revestimientos', 2432),
#  ('patio.', 2428),
#  ('total:', 2424),
#  ('inmobiliario', 2422),
#  ('pleno', 2421),
#  ('anodizado', 2410),
#  ('verificaci\xc3\xb3n', 2407),
#  ('belgrano', 2404),
#  ('locales', 2384),
#  ('vigente', 2374),
#  ('privado', 2370),
#  ('oficina', 2362),
#  ('descubierta', 2359),
#  ('libertador', 2348),
#  ('compartimentado', 2341),
#  ('sitio', 2327),
#  ('lotes', 2325),
#  ('cuentan', 2312),
#  ('laguna', 2308),
#  ('otras', 2302),
#  ('subsuelo', 2295),
#  ('port\xc3\xb3n', 2291),
#  ('tradicional', 2285),
#  ('trata', 2280),
#  ('boulevard', 2278),
#  ('ferrum', 2277),
#  ('calidad,', 2266),
#  ('modificado', 2252),
#  ('frio', 2245),
#  ('(pedido', 2243),
#  ('orientaci\xc3\xb3n', 2237),
#  ('ba\xc3\xb1os,', 2232),
#  ('ubicaci\xc3\xb3n,', 2227),
#  ('isla', 2218),
#  ('cubierta:', 2202),
#  ('melamina', 2202),
#  ('chapa', 2199),
#  ('conformidad', 2199),
#  ('buenas', 2198),
#  ('comercial,', 2197),
#  ('cer\xc3\xa1mica', 2196),
#  ('terrazas', 2192),
#  ('lateral', 2192),
#  ('alacena', 2185),
#  ('nordelta', 2175),
#  ('master', 2169),
#  ('aterrazado', 2167),
#  ('golf', 2164),
#  ('iluminaci\xc3\xb3n', 2161),
#  ('exclusivo', 2154),
#  ('categoria', 2154),
#  ('calor', 2153),
#  ('media', 2152),
#  ('parrillas', 2151),
#  ('ventanal', 2149),
#  ('desarrollado', 2147),
#  ('cer\xc3\xa1micos', 2143),
#  ('pr\xc3\xb3ximo', 2141),
#  ('radiadores', 2138),
#  ('frentes', 2138),
#  ('chimenea', 2137),
#  ('pared', 2134),
#  ('normativa', 2133),
#  ('artefacto', 2130),
#  ('contrafrente,', 2130),
#  ('cubierta.', 2115),
#  ('pago:', 2115),
#  ('comprar', 2107),
#  ('cochera.', 2102),
#  ('moderna', 2091),
#  ('jardines', 2088),
#  ('consulta', 2087),
#  ('acondicionado.', 2085),
#  ('completos.', 2079),
#  ('ramal', 2073),
#  ('indicados', 2071),
#  ('pocas', 2069),
#  ('granito,', 2067),
#  ('blanco', 2067),
#  ('living.', 2066),
#  ('tanto', 2065),
#  ('aprox', 2060),
#  ('mayor', 2055),
#  ('\xc3\xa1rea', 2054),
#  ('parquet,', 2050),
#  ('fijas', 2046),
#  ('carpinter\xc3\xada', 2045),
#  ('expensas.', 2044),
#  ('tel.', 2041),
#  ('climatizada', 2040),
#  ('alquiler', 2038),
#  ('jacuzzi', 2035),
#  ('materiales', 2034),
#  ('play', 2033),
#  ('pasos', 2027),
#  ('mensuales', 2027),
#  ('parquizado', 2025),
#  ('precios', 2025),
#  ('colegio', 2016),
#  ('ducha.', 2014),
#  ('est\xc3\x83\xc2\xa1', 2012),
#  ('operaciones', 2011),
#  ('m\xc3\xbaltiples', 2008),
#  ('ruta', 2005),
#  ('central,', 2000),
#  ('griferia', 1999),
#  ('entorno', 1997),
#  ('americana', 1993),
#  ('nueva', 1992),
#  ('r\xc3\xado', 1964),
#  ('barrios', 1960),
#  ('33-60234274-9c.u.c.i.c.b.a.', 1959),
#  ('accesos', 1957),
#  ('bajos', 1956),
#  ('control', 1953),
#  ('hall,', 1952),
#  ('com\xc3\xban', 1950),
#  ('vicente', 1942),
#  ('corresponda.venta', 1941),
#  ('integrado', 1940),
#  ('cumplimente', 1939),
#  ('coti)', 1938),
#  ('coraz\xc3\xb3n', 1933),
#  ('divisible', 1929),
#  ('porcelanato,', 1929),
#  ('estos', 1928),
#  ('consulte', 1926),
#  ('ladrillo', 1926),
#  ('2439/08', 1924),
#  ('marco', 1921),
#  ('tener', 1918),
#  ('jard\xc3\xadn.', 1917),
#  ('bauleras', 1917),
#  ('inmobiliarios.', 1914),
#  ('estrenar,', 1914),
#  ('meramente', 1913),
#  ('rivadavia', 1908),
#  ('ser\xc3\xa1', 1906),
#  ('radiante,', 1904),
#  ('peque\xc3\xb1o', 1903),
#  ('estrenar.', 1900),
#  ('sujetas', 1889),
#  ('cemento', 1888),
#  ('s.a.', 1885),
#  ('s.a.cuit', 1882),
#  ('habitacion', 1879),
#  ('pablo', 1874),
#  ('2371/08,', 1873),
#  ('estan', 1869),
#  ('garaje', 1864),
#  ('(con', 1863),
#  ('hidromasaje', 1859),
#  ('dpto', 1857),
#  ('estufa', 1854),
#  ('similar', 1852),
#  ('carlos', 1851),
#  ('parquet.', 1844),
#  ('terminaci\xc3\xb3n', 1842),
#  ('isidro', 1840),
#  ('nuestra', 1838),
#  ('sauna,', 1830),
#  ('monocomando', 1830),
#  ('actualmente', 1827),
#  ('mts2', 1824),
#  ('diciembre', 1823),
#  ('equipado', 1822),
#  ('ppal', 1819),
#  ('pero', 1815),
#  ('casas', 1802),
#  ('consignado', 1796),
#  ('consignadas', 1789),
#  ('lavarropas', 1788),
#  ('el\xc3\xa9ctrica', 1780),
#  ('individuales', 1779),
#  ('gastos', 1778),
#  ('hojas', 1768),
#  ('escritura', 1767),
#  ('construida', 1767),
#  ('boleto', 1766),
#  ('norte,', 1766),
#  ('modelo', 1764),
#  ('antig\xc3\xbcedad', 1763),
#  ('martin', 1763),
#  ('integrada.', 1751),
#  ('yaryura', 1748),
#  ('obtenci\xc3\xb3n', 1739),
#  ('cubierto,', 1739),
#  ('opcional', 1738),
#  ('pintura', 1737),
#  ('parrillas,', 1737),
#  ('c\xc3\xb3modo', 1734),
#  ('encontramos', 1734),
#  ('exteriores', 1733),
#  ('(uno', 1731),
#  ('laundry.', 1729),
#  ('igarzabal', 1729),
#  ('3154', 1727),
#  ('gas,', 1727),
#  ('exterior:', 1722),
#  ('disponibles', 1721),
#  ('mediante', 1719),
#  ('house', 1718),
#  ('espejo', 1717),
#  ('escalera.', 1716),
#  ('colectivos', 1712),
#  ('segunda', 1712),
#  ('parciales', 1709),
#  ('acceso,', 1709),
#  ('saldo', 1703),
#  ('desarrollo', 1700),
#  ('minutos', 1700),
#  ('dadas', 1698),
#  ('julio', 1697),
#  ('alacena,', 1697),
#  ('jard\xc3\xadn,', 1692),
#  ('ducha,', 1692),
#  ('mejores', 1691),
#  ('entrada.', 1685),
#  ('\xc3\xbaltima', 1681),
#  ('ventilaci\xc3\xb3n', 1681),
#  ('comunes', 1679),
#  ('baja.', 1674),
#  ('compuesto', 1674),
#  ('seg\xc3\xban', 1673),
#  ('nordelta,', 1673),
#  ('tenis,', 1672),
#  ('balcon,', 1663),
#  ('contractual.', 1663),
#  ('grifer\xc3\xadas', 1662),
#  ('propiedad.', 1661),
#  ('guardado', 1656),
#  ('numerosas', 1655),
#  ('equipo', 1639),
#  ('hormig\xc3\xb3n', 1638),
#  ('flotantes', 1633),
#  ('recepcion', 1626),
#  ('consultar', 1625),
#  ('ba\xc3\x83\xc2\xb1os', 1620),
#  ('inmueble:', 1618),
#  ('pilar', 1618),
#  ('m\xc3\x83\xc2\xa1s', 1618),
#  ('bomba', 1614),
#  ('misma', 1614),
#  ('entrepiso', 1612),
#  ('sup.', 1610),
#  ('cocinas', 1603),
#  ('estacionamiento', 1597),
#  ('preparada', 1595),
#  ('oeste', 1595),
#  ('dimensiones', 1592),
#  ('verde', 1592),
#  ('sauna', 1585),
#  ('principal,', 1580),
#  ('marzo', 1577),
#  ('septiembre', 1575),
#  ('nro.', 1570),
#  ('separado', 1567),
#  ('mariano', 1566),
#  ('balanceado', 1566),
#  ('estructura', 1564),
#  ('empresa', 1551),
#  ('s\xc3\xb3lo', 1551),
#  ('ladrillos', 1550),
#  ('gym,', 1549),
#  ('ceramicos', 1549),
#  ('ba\xc3\x91os', 1547),
#  ('plano', 1544),
#  ('parque,', 1539),
#  ('pozo', 1531),
#  ('nordelta.', 1529),
#  ('luminosa', 1526),
#  ('instalaciones', 1526),
#  ('balcon.', 1525),
#  ('completa,', 1521),
#  ('ba\xc3\x83\xc2\xb1o.', 1520),
#  ('acondicionados', 1518),
#  ('tigre', 1515),
#  ('porton', 1515),
#  ('ajuste.', 1513),
#  ('jose', 1513),
#  ('ofrece', 1512),
#  ('(coti),', 1511),
#  ('ceramicos.', 1507),
#  ('disfrutar', 1507),
#  ('informativo', 1506),
#  ('similar,', 1504),
#  ('semicubierta', 1500),
#  ('2017', 1500),
#  ('ba\xc3\xb1era.', 1499),
#  ('almagro', 1499),
#  ('(sucursales', 1494),
#  ('tramite', 1492),
#  ('mayo', 1489),
#  ('cabildo', 1489),
#  ('hacer', 1488),
#  ('cortinas', 1488),
#  ('bienes', 1488),
#  ('carpinter\xc3\xadas', 1483),
#  ('inmobiliario.', 1480),
#  ('roca', 1480),
#  ('desarrolla', 1475),
#  ('recepcion,', 1471),
#  ('normas', 1467),
#  ('gris', 1467),
#  ('mucha', 1467),
#  ('vender', 1466),
#  ('vivir', 1464),
#  ('luego', 1464),
#  ('nuevo,', 1462),
#  ('proximo', 1459),
#  ('porcelanato.', 1452),
#  ('estar,', 1452),
#  ('centro)aviso', 1450),
#  ('cochera,', 1450),
#  ('quincho,', 1450),
#  ('encuentran', 1449),
#  ('avenidas', 1445),
#  ('web:', 1442),
#  ('jacuzzi,', 1442),
#  ('vidrios', 1440),
#  ('varias', 1440),
#  ('dual', 1438),
#  ('distribuidor', 1434),
#  ('inoxidable.', 1430),
#  ('dorm', 1428),
#  ('informacion', 1425),
#  ('alta,', 1424),
#  ('podr\xc3\xa1n', 1424),
#  ('casa,', 1421),
#  ('nuevo.', 1411),
#  ('roble', 1410),
#  ('chimenea,', 1410),
#  ('fr\xc3\xado', 1409),
#  ('natural,', 1406),
#  ('pasante', 1405),
#  ('mesada.', 1401),
#  ('cuartos', 1399),
#  ('exterior.', 1393),
#  ('martilleros', 1393),
#  ('(res.', 1389),
#  ('vidriado', 1385),
#  ('propietario,', 1382),
#  ('autopista', 1382),
#  ('inoxidable,', 1375),
#  ('ramos', 1374),
#  ('edificio.', 1373),
#  ('natural.', 1370),
#  ('comun', 1369),
#  ('planta,', 1367),
#  ('federico', 1366),
#  ('centros', 1363),
#  ('rejas', 1363),
#  ('acepta', 1360),
#  ('condominio', 1357),
#  ('tigre,', 1353),
#  ('cocheras,', 1353),
#  ('opcionales', 1353),
#  ('reciclada', 1351),
#  ('calles', 1349),
#  ('contactate', 1348),
#  ('altura,', 1347),
#  ('fecha', 1345),
#  ('aires,', 1345),
#  ('b\xc3\xbasqueda', 1344),
#  ('mat.', 1344),
#  ('mts,', 1343),
#  ('playroom,', 1342),
#  ('cr\xc3\x89dito', 1340),
#  ('marmol', 1339),
#  ('acondicionado,', 1339),
#  ('luminosos', 1338),
#  ('negro', 1337),
#  ('cielorrasos', 1332),
#  ('construccion', 1332),
#  ('cubierta,', 1331),
#  ('corredizas', 1330),
#  ('crespo', 1328),
#  ('cerramiento', 1327),
#  ('aluminio,', 1322),
#  ('venta,', 1320),
#  ('categor\xc3\xada.', 1313),
#  ('cubierto.', 1313),
#  ('suministrados', 1311),
#  ('shopping', 1310),
#  ('boedo,', 1310),
#  ('lado', 1309),
#  ('directa', 1309),
#  ('comerciales', 1306),
#  ('c\xc3\xb3moda', 1305),
#  ('financiado', 1303),
#  ('country', 1302),
#  ('superficies,', 1301),
#  ('casa.', 1301),
#  ('ca\xc3\xb1er\xc3\xadas', 1300),
#  ('radiadores.', 1300),
#  ('splits', 1298),
#  ('ba\xc3\x83o', 1298),
#  ('financiacion', 1294),
#  ('zonas', 1294),
#  ('ubicaci\xc3\x93n', 1293),
#  ('colegios,', 1287),
#  ('principales', 1285),
#  ('ajustes.', 1284),
#  ('escalera,', 1281),
#  ('cuales', 1279),
#  ('avanzado', 1277),
#  ('circuito', 1277),
#  ('3,50', 1275),
#  ('consultas', 1275),
#  ('mitre', 1273),
#  ('ba\xc3\xb1era,', 1271),
#  ('piscina.', 1269),
#  ('mucho', 1267),
#  ('video', 1265),
#  ('permite', 1262),
#  ('exclusiva', 1260),
#  ('pulm\xc3\xb3n', 1260),
#  ('loza', 1258),
#  ('auto.', 1257),
#  ('planta.', 1254),
#  ('4516', 1252),
#  ('1354mar\xc3\xada', 1252),
#  ('corrido,', 1252),
#  ('ccs.)', 1250),
#  ('lomas', 1248),
#  ('barandas', 1248),
#  ('\xc3\xbanico', 1246),
#  ('cantidad', 1245),
#  ('herrajes', 1244),
#  ('jardin,', 1244),
#  ('tasaciones', 1242),
#  ('ingresa', 1241),
#  ('real', 1239),
#  ('cabina', 1236),
#  ('resto', 1234),
#  ('luminosidad', 1234),
#  ('gas.', 1234),
#  ('el\xc3\xa9ctrico,', 1231),
#  ('privado,', 1231),
#  ('auto,', 1231),
#  ...]

# %%
sorted(contador.items())
# Out:
# [('\x03con', 1),
#  ('!!!!', 262),
#  ('!!!!!', 103),
#  ('!!!!!!', 52),
#  ('!!!!!!!', 12),
#  ('!!!!!!!!', 13),
#  ('!!!!!!!!!', 5),
#  ('!!!!!!!!!!', 4),
#  ('!!!!!!!!!!!', 4),
#  ('!!!!!!!!!!!!', 1),
#  ('!!!!!!!!!!!!!', 1),
#  ('!!!!!!!!!!!!!!', 2),
#  ('!!!!!!!!!!!!!!!', 2),
#  ('!!!!!!!!!!!!!!!!!', 1),
#  ('!!!!!!!!!!!!!!!!!!', 2),
#  ('!!!!!!!!!!!!!!!!!!!!!!', 2),
#  ('!!!!!!!!!!!!!!!!!!!!!!!!!!', 1),
#  ('!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!el', 7),
#  ('!!!!!!!!!!!!!!!!!!!!!!muy', 1),
#  ('!!!!!!!!!!!!!!!!!!!!casa', 2),
#  ('!!!!!!!!!!!!!!!!!!!en', 2),
#  ('!!!!!!!!!!!!!!!!!!!ph', 2),
#  ('!!!!!!!!!!!!!!!!!!!reservado', 8),
#  ('!!!!!!!!!!!!!!!!!!pisos', 1),
#  ('!!!!!!!!!!!!!!!!dormitorio', 2),
#  ('!!!!!!!!!!!!!!!!planta', 1),
#  ('!!!!!!!!!!!!!!excelente', 1),
#  ('!!!!!!!!!!!!orientacion', 2),
#  ('!!!!!!!!!!!..............', 1),
#  ('!!!!!!!!!!!las', 1),
#  ('!!!!!!!!!!!totalmente', 1),
#  ('!!!!!!!!!!financiacion', 2),
#  ('!!!!!!!!!!muy', 4),
#  ('!!!!!!!!!!se', 1),
#  ('!!!!!!!!!!seguridad', 1),
#  ('!!!!!!!!!lote', 1),
#  ('!!!!!!!!!seguridad', 1),
#  ('!!!!!!!!!todas', 2),
#  ('!!!!!!!!!zuker', 1),
#  ('!!!!!!!!"a', 1),
#  ('!!!!!!!!2', 1),
#  ('!!!!!!!!financiacion', 1),
#  ('!!!!!!!.bajo', 1),
#  ('!!!!!!!el', 1),
#  ('!!!!!!!esta', 3),
#  ('!!!!!!!excelente', 8),
#  ('!!!!!!!gabriela', 2),
#  ('!!!!!!!si', 1),
#  ('!!!!!!!venta', 1),
#  ('!!!!!!,', 1),
#  ('!!!!!!.', 1),
#  ('!!!!!!....apta', 1),
#  ('!!!!!![', 2),
#  ('!!!!!!baulera', 1),
#  ('!!!!!!con', 1),
#  ('!!!!!!consulte..', 1),
#  ('!!!!!!dise\xc3\x83\xc2\xb1o', 1),
#  ('!!!!!!edificio', 1),
#  ('!!!!!!en', 3),
#  ('!!!!!!espectacular', 3),
#  ('!!!!!!excelentes', 1),
#  ('!!!!!!hall', 2),
#  ('!!!!!!jorge', 4),
#  ('!!!!!!martillero', 1),
#  ('!!!!!!muy', 1),
#  ('!!!!!!pa:', 1),
#  ('!!!!!!pablo', 1),
#  ('!!!!!!planta', 2),
#  ('!!!!!!tasaciones', 2),
#  ('!!!!!!zona', 1),
#  ('!!!!!"las', 2),
#  ('!!!!!*', 4),
#  ('!!!!!*edificio:', 1),
#  ('!!!!!--amplio', 1),
#  ('!!!!!-3', 1),
#  ('!!!!!.', 4),
#  ('!!!!!2', 1),
#  ('!!!!![', 2),
#  ('!!!!!acepta', 1),
#  ('!!!!!alquiler', 1),
#  ('!!!!!apto', 1),
#  ('!!!!!casa', 2),
#  ('!!!!!chalet', 1),
#  ('!!!!!cochera', 1),
#  ('!!!!!cochera;', 1),
#  ('!!!!!cocina', 7),
#  ('!!!!!combinar', 1),
#  ('!!!!!comoda', 1),
#  ('!!!!!el', 2),
#  ('!!!!!en', 2),
#  ('!!!!!entrega', 1),
#  ('!!!!!excelente', 4),
#  ('!!!!!expensas', 1),
#  ('!!!!!hall', 1),
#  ('!!!!!hay', 1),
#  ('!!!!!imperdible!!!!!av.', 3),
#  ('!!!!!increible', 1),
#  ('!!!!!martillero', 1),
#  ('!!!!!matriculado:marcelo', 1),
#  ('!!!!!metros', 1),
#  ('!!!!!oportunidad!!!!!!', 1),
#  ('!!!!!orwel', 5),
#  ('!!!!!p.b:', 1),
#  ('!!!!!pb:hall', 1),
#  ('!!!!!piso', 1),
#  ('!!!!!todo', 1),
#  ('!!!!!vale', 1),
#  ('!!!!!venta', 1),
#  ('!!!!!visitela', 2),
#  ('!!!!!zuker', 1),
#  ('!!!!"las', 1),
#  ('!!!!"se', 1),
#  ('!!!!*', 2),
#  ('!!!!,', 2),
#  ('!!!!-', 1),
#  ('!!!!.', 9),
#  ('!!!!........', 1),
#  ('!!!!.seguridad', 1),
#  ('!!!!//', 2),
#  ('!!!!105', 6),
#  ('!!!!165', 6),
#  ('!!!!1matriculado:gast\xc3\xb3n', 1),
#  ('!!!!1\xc2\xb0', 2),
#  ('!!!!31,80', 1),
#  ('!!!![', 1),
#  ('!!!!a', 1),
#  ('!!!!amplia', 2),
#  ('!!!!amplio', 1),
#  ('!!!!apto', 2),
#  ('!!!!casa', 2),
#  ('!!!!cochera', 4),
#  ('!!!!cocina', 3),
#  ('!!!!con', 1),
#  ('!!!!consultanos', 1),
#  ('!!!!consultar', 17),
#  ('!!!!despu\xc3\xa9s', 1),
#  ('!!!!distribuci\xc3\x83\xc2\xb3n:', 1),
#  ('!!!!distribuci\xc3\xb3n:', 2),
#  ('!!!!dormitorio', 1),
#  ('!!!!edificio', 1),
#  ('!!!!el', 16),
#  ('!!!!en', 1),
#  ('!!!!espectacular', 2),
#  ('!!!!esta', 1),
#  ('!!!!estudio', 2),
#  ('!!!!excelente', 1),
#  ('!!!!exp', 1),
#  ('!!!!expensas', 4),
#  ('!!!!frente', 1),
#  ('!!!!gabriela', 2),
#  ('!!!!galeria-', 2),
#  ('!!!!hall,', 1),
#  ('!!!!hay', 1),
#  ('!!!!hermoso', 1),
#  ('!!!!hermoso!!!!', 1),
#  ('!!!!increible', 1),
#  ('!!!!la', 3),
#  ('!!!!las', 5),
#  ('!!!!living', 3),
#  ('!!!!llamenos', 2),
#  ('!!!!lote', 1),
#  ('!!!!luminoso.', 1),
#  ('!!!!martillero', 3),
#  ('!!!!matriculado:gast\xc3\xb3n', 1),
#  ('!!!!morelli', 1),
#  ('!!!!no', 1),
#  ('!!!!norde', 2),
#  ('!!!!orwel', 13),
#  ('!!!!oslo', 1),
#  ('!!!!pablo', 1),
#  ('!!!!palier', 1),
#  ('!!!!para', 1),
#  ('!!!!pastori', 5),
#  ('!!!!pb', 1),
#  ('!!!!pb:', 1),
#  ('!!!!pb:te', 1),
#  ('!!!!piso', 1),
#  ('!!!!planta', 4),
#  ('!!!!posesi\xc3\x93n', 11),
#  ('!!!!posibilidad', 6),
#  ('!!!!precioso', 1),
#  ('!!!!proyecto', 1),
#  ('!!!!se', 1),
#  ('!!!!sobre', 1),
#  ('!!!!solo', 1),
#  ('!!!!son', 3),
#  ('!!!!sucursal', 1),
#  ('!!!!tambi\xc3\x89n', 1),
#  ('!!!!te:', 1),
#  ('!!!!tel.', 1),
#  ('!!!!the', 1),
#  ('!!!!todas', 1),
#  ('!!!!todo', 2),
#  ('!!!!toman', 1),
#  ('!!!!tres', 2),
#  ('!!!!unidades', 1),
#  ('!!!!vale', 3),
#  ('!!!!venta', 1),
#  ('!!!!viva', 1),
#  ('!!!!zona', 1),
#  ('!!!!zonificacion:', 1),
#  ('!!!!\xe2\x80\x9cen', 1),
#  ('!!!"se', 8),
#  ('!!!(', 1),
#  ('!!!((((', 1),
#  ('!!!(no', 2),
#  ('!!!)puerta', 1),
#  ('!!!*', 6),
#  ('!!!*acepta', 1),
#  ('!!!*se', 1),
#  ('!!!,', 7),
#  ('!!!,hall', 1),
#  ('!!!,palier', 1),
#  ('!!!-', 8),
#  ('!!!-ingrese', 1),
#  ('!!!-super', 2),
#  ('!!!.', 19),
#  ('!!!.,[', 1),
#  ('!!!.,lugar', 1),
#  ('!!!.-la', 2),
#  ('!!!...', 1),
#  ('!!!....', 2),
#  ('!!!...........................................se', 1),
#  ('!!!.......................no', 1),
#  ('!!!...a', 1),
#  ('!!!...exclusivos', 2),
#  ('!!!.baulera.edificio', 1),
#  ('!!!.cocheras', 1),
#  ('!!!.las', 1),
#  ('!!!.pb:', 3),
#  ('!!!.se', 2),
#  ('!!!105', 14),
#  ('!!!14', 2),
#  ('!!!15', 4),
#  ('!!!1\xc2\xba', 1),
#  ('!!!2', 4),
#  ('!!!3', 4),
#  ('!!!4', 1),
#  ('!!!487', 2),
#  ('!!!49', 2),
#  ('!!!5\xc2\xb0piso', 2),
#  ('!!!60', 2),
#  ('!!!60metros', 1),
#  ('!!!72', 1),
#  ('!!!92', 2),
#  ("!!!::d'aria::40058000:", 1),
#  ('!!!===', 7),
#  ('!!![', 6),
#  ('!!!a', 17),
#  ('!!!aacondicionado', 1),
#  ('!!!actualmente', 2),
#  ('!!!aire', 1),
#  ('!!!al', 6),
#  ('!!!am', 1),
#  ('!!!amenities-', 11),
#  ('!!!amenities:', 2),
#  ('!!!amplia', 2),
#  ('!!!amplio', 1),
#  ('!!!antonella', 1),
#  ('!!!apto', 10),
#  ('!!!aviso', 1),
#  ('!!!bah\xc3\x83a', 1),
#  ('!!!barrio', 1),
#  ('!!!cadahia', 1),
#  ('!!!caracteristicascarpinterias', 4),
#  ('!!!carpinter\xc3\x83\xc2\xada', 1),
#  ('!!!casa', 2),
#  ('!!!cespedes', 1),
#  ('!!!chalet', 1),
#  ('!!!cochera', 12),
#  ('!!!cocina', 2),
#  ('!!!colectivos:5,', 1),
#  ('!!!comunicate', 1),
#  ('!!!con', 11),
#  ('!!!construccion', 1),
#  ('!!!consultar', 3),
#  ('!!!consulte', 2),
#  ('!!!contacto:', 1),
#  ('!!!contamos', 5),
#  ('!!!david', 1),
#  ('!!!departamento', 4),
#  ('!!!depto', 1),
#  ('!!!deptos', 7),
#  ('!!!desarrollado', 1),
#  ('!!!descripci\xc3\x83\xc2\xb3n:pb..', 1),
#  ('!!!desde', 1),
#  ('!!!digno', 4),
#  ('!!!discepolo', 1),
#  ('!!!divisible,', 1),
#  ('!!!dormitorio', 1),
#  ('!!!dormitorio,', 1),
#  ('!!!el', 25),
#  ('!!!en', 8),
#  ('!!!entrega', 5),
#  ('!!!espectacular', 6),
#  ('!!!esta', 1),
#  ('!!!estilo', 1),
#  ('!!!excelente', 22),
#  ('!!!excelentes', 1),
#  ('!!!exclusivos', 1),
#  ('!!!expensas', 6),
#  ('!!!expensas:', 1),
#  ('!!!exterior:', 1),
#  ('!!!fecha', 1),
#  ('!!!fgk', 1),
#  ('!!!forma', 12),
#  ('!!!gabriela', 3),
#  ('!!!gran', 3),
#  ('!!!grupo', 4),
#  ('!!!hall', 5),
#  ('!!!hay', 5),
#  ('!!!hermosa', 6),
#  ('!!!hermoso', 2),
#  ('!!!horario', 1),
#  ('!!!i', 1),
#  ('!!!ideal', 4),
#  ('!!!impecable', 5),
#  ('!!!impeclabe', 3),
#  ('!!!importante', 3),
#  ('!!!incluye', 1),
#  ('!!!incre\xc3\xadble', 2),
#  ('!!!ingrese', 5),
#  ('!!!inmejorable', 3),
#  ('!!!instalaci\xc3\xb3n', 4),
#  ('!!!inversi\xc3\x93n', 9),
#  ('!!!jardin', 1),
#  ('!!!la', 5),
#  ('!!!las', 15),
#  ('!!!lavadero', 1),
#  ('!!!lindisima', 1),
#  ('!!!listo', 1),
#  ('!!!living', 5),
#  ('!!!living,', 1),
#  ('!!!living-comedor.', 1),
#  ('!!!llamanos', 2),
#  ('!!!local', 4),
#  ('!!!los', 1),
#  ('!!!lucas', 1),
#  ('!!!luminoso', 3),
#  ('!!!matricula', 3),
#  ('!!!matriculado:gast\xc3\xb3n', 1),
#  ('!!!medidas', 2),
#  ('!!!medios', 1),
#  ('!!!migliorisi', 1),
#  ('!!!moderno', 1),
#  ('!!!mono', 2),
#  ('!!!muy', 10),
#  ('!!!m\xc3\xb3vil:', 12),
#  ('!!!no', 2),
#  ('!!!nota:', 1),
#  ('!!!oportunidad!!!', 1),
#  ('!!!orientaci\xc3\xb3n', 2),
#  ('!!!orwel', 5),
#  ('!!!p.b.', 1),
#  ('!!!p.b:', 2),
#  ('!!!pa:', 1),
#  ('!!!palier', 1),
#  ('!!!para', 5),
#  ('!!!pastori', 18),
#  ('!!!pb', 1),
#  ('!!!pb-', 1),
#  ('!!!pb:', 7),
#  ('!!!pegado', 1),
#  ('!!!ph', 1),
#  ('!!!piso', 3),
#  ('!!!planta', 2),
#  ('!!!pod\xc3\xa9s', 1),
#  ('!!!precio', 1),
#  ('!!!propiedad', 4),
#  ('!!!pta', 2),
#  ('!!!pta.', 1),
#  ('!!!rcm', 1),
#  ('!!!realizamos', 7),
#  ('!!!recepcion.', 2),
#  ('!!!renta', 1),
#  ('!!!reservado', 43),
#  ('!!!retasado!!!!!!!!!!', 2),
#  ('!!!riobamba', 1),
#  ('!!!roilands', 4),
#  ('!!!santa', 2),
#  ('!!!se', 16),
#  ('!!!sobre', 3),
#  ('!!!su', 1),
#  ('!!!sucursal', 13),
#  ('!!!sup.', 6),
#  ('!!!super', 2),
#  ('!!!superficie', 1),
#  ('!!!te', 1),
#  ('!!!te:', 1),
#  ('!!!terraza', 4),
#  ('!!!the', 9),
#  ('!!!todas', 4),
#  ('!!!todo', 2),
#  ('!!!toman', 12),
#  ('!!!ubicaci\xc3\xb3n:', 4),
#  ('!!!ubicado', 8),
#  ('!!!uf', 2),
#  ('!!!ultimas', 4),
#  ('!!!unidad', 3),
#  ('!!!unidades', 1),
#  ('!!!vale', 3),
#  ('!!!valor', 1),
#  ('!!!vende', 1),
#  ('!!!venta', 6),
#  ('!!!ver', 2),
#  ('!!!visitela', 2),
#  ('!!!visitela!!![', 1),
#  ('!!!visitelo!!![', 1),
#  ('!!!visitelo!!!digno', 1),
#  ('!!!y', 4),
#  ('!!!\xc3\x82\xc2\xa1todos', 4),
#  ('!!!\xc3\x83nico', 2),
#  ('!!!\xe2\x80\x9cen', 2),
#  ('!!*apto', 1),
#  ('!!---', 4),
#  ('!!------', 1),
#  ('!!---nota:', 2),
#  ('!!-lote', 2),
#  ('!!.-', 3),
#  ('!!...digna', 1),
#  ('!!..consulte', 2),
#  ('!!.la', 1),
#  ('!!.las', 6),
#  ('!!1)', 1),
#  ('!!150', 1),
#  ('!!89', 1),
#  ('!!===', 2),
#  ('!!agenda', 4),
#  ('!!al', 1),
#  ('!!amplio', 5),
#  ('!!antiguedad', 1),
#  ('!!antonella', 2),
#  ('!!apto', 6),
#  ('!!aviso', 1),
#  ('!!canerias', 1),
#  ('!!casa', 1),
#  ('!!cercana', 1),
#  ('!!cinco', 1),
#  ('!!clasico', 1),
#  ('!!cochera', 1),
#  ('!!como', 6),
#  ('!!con', 3),
#  ('!!consultar', 2),
#  ('!!consultas', 1),
#  ('!!consulte', 1),
#  ('!!corredor', 1),
#  ('!!cuenta', 2),
#  ('!!departamento', 3),
#  ('!!departamento:', 1),
#  ('!!departamentos', 3),
#  ('!!desarrollada', 6),
#  ('!!detalles', 7),
#  ('!!detalles:', 1),
#  ('!!dicha', 2),
#  ('!!dispone', 8),
#  ('!!divisible,', 1),
#  ('!!dos', 4),
#  ('!!edificio', 1),
#  ('!!edificio:el', 1),
#  ('!!el', 4),
#  ('!!elegante', 1),
#  ('!!en', 6),
#  ('!!espacio', 4),
#  ('!!espectacular', 1),
#  ('!!estar', 2),
#  ('!!estilo', 1),
#  ('!!estructura:esta', 1),
#  ('!!estudio', 2),
#  ('!!excelente', 15),
#  ('!!expensas', 1),
#  ('!!formas', 5),
#  ('!!gabriela', 2),
#  ('!!gran', 1),
#  ('!!grupo', 2),
#  ('!!gustavo', 1),
#  ('!!hall', 1),
#  ('!!ideal', 4),
#  ('!!impecable', 1),
#  ('!!ingrese', 4),
#  ('!!juncal', 1),
#  ('!!la', 2),
#  ('!!las', 16),
#  ('!!lindo', 1),
#  ('!!lind\xc3\x8dsimo', 1),
#  ('!!living', 6),
#  ('!!living-comedor', 1),
#  ('!!mas', 3),
#  ('!!matriculada:juliana', 1),
#  ('!!muy', 15),
#  ('!!no', 3),
#  ('!!opcional', 1),
#  ('!!oportunidad', 1),
#  ('!!palier', 1),
#  ('!!para', 10),
#  ('!!pb', 1),
#  ('!!pb:', 1),
#  ('!!pb:cocina', 2),
#  ('!!pisos', 2),
#  ('!!planta', 6),
#  ('!!por', 1),
#  ('!!precioso!!!', 2),
#  ('!!propiedad', 1),
#  ('!!reci\xc3\xa9n', 4),
#  ('!!se', 12),
#  ('!!seguridad', 1),
#  ('!!semipisos', 1),
#  ('!!son', 1),
#  ('!!superficie', 2),
#  ('!!tambi\xc3\x89n', 15),
#  ('!!tasaciones', 1),
#  ('!!tiene', 1),
#  ('!!todo', 5),
#  ('!!toilette', 2),
#  ('!!ubicado', 1),
#  ('!!una', 1),
#  ('!!unidad', 1),
#  ('!!vendo', 1),
#  ('!!venta', 1),
#  ('!!vila', 1),
#  ('!!zaduh', 1),
#  ('!!\xe2\x80\x9den', 21),
#  ('!*********', 1),
#  ('!*venta', 1),
#  ('!,piscina', 2),
#  ('!----------optimas', 1),
#  ('!-con', 1),
#  ('!-escrituracion', 1),
#  ('!-quincho-parrilla', 1),
#  ('!-superficie', 2),
#  ('!.1\xc2\xba', 1),
#  ('!.amenities', 1),
#  ('!.consulte', 1),
#  ('!.departamento', 1),
#  ('!.edificio', 1),
#  ('!.excelente', 1),
#  ('!.gran', 3),
#  ('!.las', 1),
#  ('!.norde', 4),
#  ('!.ubicacion', 1),
#  ('!270', 1),
#  ('!33,82', 1),
#  ('!agua', 2),
#  ('!ambiente', 3),
#  ('!amenities', 2),
#  ('!amenities:', 1),
#  ('!anticipo', 1),
#  ('!antonella', 1),
#  ('!apto', 3),
#  ('!asociate', 1),
#  ('!av.', 11),
#  ('!aviso', 4),
#  ('!bajas', 4),
#  ('!calefacci\xc3\xb3n', 1),
#  ('!carpinteria', 1),
#  ('!casa', 3),
#  ('!cl\xc3\xa1sico', 1),
#  ('!cochera', 1),
#  ('!con', 1),
#  ('!consta', 1),
#  ('!consultar', 2),
#  ('!consulte', 2),
#  ('!coordinar', 1),
#  ('!coordine', 1),
#  ('!corriente', 1),
#  ('!cuenta', 2),
#  ('!c\xc3\xb3digo', 2),
#  ('!departamento', 4),
#  ('!descripcion', 1),
#  ('!dise\xc3\xb1ada', 1),
#  ('!divina', 1),
#  ('!doble', 1),
#  ('!dpto', 1),
#  ('!duplex', 1),
#  ('!edificio', 4),
#  ('!entrada', 4),
#  ('!er.', 1),
#  ('!esperamos', 2),
#  ('!esta', 7),
#  ('!excelente', 7),
#  ('!excelentes', 1),
#  ('!expensas', 1),
#  ('!expensas:', 1),
#  ('!extraordinaria', 1),
#  ('!frente', 1),
#  ('!godoy', 1),
#  ('!hall', 3),
#  ('!hall,', 3),
#  ('!hecho', 1),
#  ('!hermoso', 2),
#  ('!hoy', 3),
#  ('!ideal', 1),
#  ('!impecable', 1),
#  ('!imponente', 2),
#  ('!importante', 1),
#  ('!informaci\xc3\x93n-calidad', 1),
#  ('!ingreso', 1),
#  ('!instalacion', 3),
#  ('!instalaci\xc3\x93n', 1),
#  ('!jardin', 2),
#  ('!las', 3),
#  ('!levit', 1),
#  ('!lindisimo', 1),
#  ('!lindismo', 2),
#  ('!liv-comedor,', 1),
#  ('!living', 8),
#  ('!locura', 1),
#  ('!lote', 1),
#  ('!matriculada:juliana', 1),
#  ('!moderna', 3),
#  ('!monoambiente', 2),
#  ('!mucho', 1),
#  ('!muy', 1),
#  ('!opcion', 1),
#  ('!pa:', 1),
#  ('!pa:suite', 1),
#  ('!pallier', 2),
#  ('!pb:', 2),
#  ('!pilares', 1),
#  ('!piso', 1),
#  ('!pisos', 5),
#  ('!planta', 4),
#  ('!posee', 1),
#  ('!reciclada', 1),
#  ('!san', 1),
#  ('!situar', 5),
#  ('!sobre', 1),
#  ('!son', 2),
#  ('!suite', 1),
#  ('!super', 1),
#  ('!s\xc3\xbaper', 5),
#  ('!tenemos', 1),
#  ('!todos', 2),
#  ('!ubicacion', 1),
#  ('!ubicado', 5),
#  ('!unamuno', 1),
#  ('!unidad', 4),
#  ('!ver', 2),
#  ('!vista', 1),
#  ('!zuker', 1),
#  ('!\xc2\xa1ver', 1),
#  ('!\xc2\xbf\xc2\xbfquer\xc3\xa9s', 2),
#  ('!\xc3\x82\xc2\xaa!!', 1),
#  ('""""', 2),
#  ('"""""', 1),
#  ('""""""', 1),
#  ('""""""""""""""""""""', 1),
#  ('""""""""""""""""""""""', 1),
#  ('"""""""""""""""""""""""""monoambiente""""""""""""""""""""""""al', 1),
#  ('"""""""""""""""""""""""venta', 1),
#  ('"""""""""""""""""""impecable', 2),
#  ('"""""""""""""""""casa', 1),
#  ('""""""""""""""""casa', 2),
#  ('""""""""""""""casa', 1),
#  ('"""""""""""""y', 1),
#  ('"""""""""""apto', 2),
#  ('"""""""""""casa', 2),
#  ('"""""""""departamentos', 2),
#  ('"""""""""dos', 2),
#  ('"""""""""monoambiente', 3),
#  ('""""""""chalet', 2),
#  ('""""""""oportunidad', 1),
#  ('""""""a', 1),
#  ('""""""casa', 1),
#  ('""""""gran', 1),
#  ('""""""imperdible""""""el', 2),
#  ('""""""preventa', 2),
#  ('"""""dos', 1),
#  ('"""""excelente', 2),
#  ('"""""se', 1),
#  ('"""""ver', 6),
#  ('""""amplio', 2),
#  ('""""apto', 1),
#  ('""""casa', 2),
#  ('""""chalet', 2),
#  ('""""complejo', 1),
#  ('""""im-pe-ca-ble"""', 1),
#  ('""""living', 1),
#  ('""""no', 1),
#  ('""""se\xc3\x91or', 1),
#  ('"""a', 1),
#  ('"""alquilado', 1),
#  ('"""con', 1),
#  ('"""unica', 1),
#  ('""a""', 1),
#  ('""apto', 6),
#  ('""bajas', 1),
#  ('""depto', 2),
#  ('""islas', 1),
#  ('""no', 1),
#  ('"\'ilva\xe2\x80\x9d', 8),
#  ('"*la', 2),
#  ('",muy', 1),
#  ('"-ba\xc3\xb1o', 1),
#  ('"-estilo', 1),
#  ('".casa', 1),
#  ('".estrat\xc3\xa9gica', 2),
#  ('"02".', 1),
#  ('"1",', 2),
#  ('"1".', 5),
#  ('"1"n\xc2\xba', 2),
#  ('"10"n\xc2\xba', 1),
#  ('"10mo', 2),
#  ('"11"', 1),
#  ('"11"n\xc2\xba', 1),
#  ('"13"', 1),
#  ('"13",', 1),
#  ('"13".', 1),
#  ('"14"', 2),
#  ('"14".', 1),
#  ('"16"', 1),
#  ('"17"para', 1),
#  ('"1\xc2\xbajunta"', 8),
#  ('"2".', 6),
#  ('"2".-', 2),
#  ('"2"n\xc2\xba', 3),
#  ('"204"venta', 1),
#  ('"21"', 1),
#  ('"26"', 1),
#  ('"28"', 4),
#  ('"2do', 1),
#  ('"3",', 1),
#  ('"3".', 1),
#  ('"3"expensas', 1),
#  ('"3"n\xc2\xba', 2),
#  ('"35"', 1),
#  ('"39"', 2),
#  ('"3er', 1),
#  ('"4"n\xc2\xba', 3),
#  ('"4000', 2),
#  ('"400m2', 2),
#  ('"43"', 3),
#  ('"47"', 2),
#  ('"4to', 3),
#  ('"5".', 1),
#  ('"5"forma', 1),
#  ('"5"n\xc2\xba', 1),
#  ('"6".', 1),
#  ('"6"forma', 1),
#  ('"6"n\xc2\xba', 1),
#  ('"7"n\xc2\xba', 2),
#  ('"8"no', 2),
#  ('"8"n\xc2\xba', 3),
#  ('"9".', 4),
#  ('"9"n\xc2\xba', 1),
#  ('"98"', 9),
#  ('"a""superficie', 10),
#  ('"a"(gran', 1),
#  ('"a")', 7),
#  ('"a"),', 1),
#  ('"a").', 4),
#  ('"a",', 96),
#  ('"a",3', 1),
#  ('"a",centro', 1),
#  ('"a",importante', 1),
#  ('"a"-', 6),
#  ('"a".', 166),
#  ('"a".!!!', 4),
#  ('"a".-', 3),
#  ('"a".[', 1),
#  ('"a".apto', 1),
#  ('"a".buenos', 1),
#  ('"a".colectivos:', 7),
#  ('"a".consultas', 1),
#  ('"a".cuenta', 1),
#  ('"a".d\'odorico', 1),
#  ('"a".departamentos', 2),
#  ('"a".excelente', 1),
#  ('"a".gran', 1),
#  ('"a".las', 1),
#  ('"a".living:', 1),
#  ('"a".local', 1),
#  ('"a"5', 1),
#  ('"a"59', 6),
#  ('"a"6', 1),
#  ('"a":', 8),
#  ('"a":ambiente', 1),
#  ('"a"a', 2),
#  ('"a"al', 1),
#  ('"a"con', 2),
#  ('"a"consultas', 1),
#  ('"a"d\'odorico', 1),
#  ('"a"el', 1),
#  ('"a"entrecalles:', 1),
#  ('"a"entrega', 1),
#  ('"a"la', 1),
#  ('"a"matr.', 1),
#  ('"a"n\xc2\xba', 3),
#  ('"a"primer', 1),
#  ('"a"si', 2),
#  ('"a-30"', 1),
#  ('"a3o"', 1),
#  ('"ab"', 3),
#  ('"ab"-', 1),
#  ('"abril"', 1),
#  ('"acacias",', 1),
#  ('"accesibilidad', 6),
#  ('"accesos', 1),
#  ('"acerbrag"', 1),
#  ('"acerbrag".', 1),
#  ('"acerbrag".2.', 16),
#  ('"acindar"', 1),
#  ('"acoyte".-', 6),
#  ('"adelanto"', 2),
#  ('"adrogue', 2),
#  ('"agencia', 1),
#  ('"aggiornados"', 1),
#  ('"agregar', 3),
#  ('"agustina', 1),
#  ('"agustinas', 6),
#  ('"ag\xc3\x9cero"-y', 1),
#  ('"aires', 1),
#  ('"alberdi".', 1),
#  ('"alberdi\xe2\x80\x9d', 8),
#  ('"alem"', 1),
#  ('"alfonso', 7),
#  ('"algo"hall', 1),
#  ('"alianza', 1),
#  ('"almagro"', 2),
#  ('"almirante', 2),
#  ('"alquilado', 1),
#  ('"alquilados', 1),
#  ('"alquiler".', 1),
#  ('"alto', 4),
#  ('"altos', 20),
#  ('"aluar"', 4),
#  ('"aluar",', 34),
#  ('"aluar.semicubiertos:', 1),
#  ('"alvear".*', 2),
#  ('"amancay"', 3),
#  ('"amaneceres', 1),
#  ('"ambar".', 1),
#  ('"amelie', 14),
#  ('"amenities"', 1),
#  ('"amoblamientos', 1),
#  ('"ampliada".', 1),
#  ('"amplio', 2),
#  ('"amplio,', 3),
#  ('"angel', 16),
#  ('"antig\xc3\x83edad:', 1),
#  ('"antipintadas"."como', 1),
#  ('"apartamentos', 1),
#  ('"apta', 2),
#  ('"apto', 67),
#  ('"aqua', 1),
#  ('"aranzay",', 2),
#  ('"arboris', 1),
#  ('"arborisubicado', 5),
#  ('"arce".', 1),
#  ('"arcos",', 1),
#  ('"arena".2', 1),
#  ('"arenas"terraza', 1),
#  ('"argos', 1),
#  ('"ariston', 2),
#  ('"ariston",', 1),
#  ('"ariston".', 1),
#  ('"arist\xc3\xb3bulo', 1),
#  ('"armado"', 1),
#  ('"armenia', 1),
#  ('"arribe\xc3\xb1os', 14),
#  ('"art', 7),
#  ('"artica', 1),
#  ('"arturo', 2),
#  ('"ascensores', 1),
#  ('"atma",', 7),
#  ('"av.', 1),
#  ('"avenida', 1),
#  ('"awaduct"', 7),
#  ('"awwa"', 1),
#  ('"ayres', 7),
#  ('"b""superficie', 10),
#  ('"b")', 3),
#  ('"b"),', 19),
#  ('"b").', 4),
#  ('"b")cons\xc3\x9altenos', 1),
#  ('"b"*', 1),
#  ('"b",', 60),
#  ('"b"-', 7),
#  ('"b"-zona', 1),
#  ('"b".', 175),
#  ('"b".*', 5),
#  ('"b".-', 4),
#  ('"b".-----------------se', 1),
#  ('"b".colectivos:', 2),
#  ('"b".consultas', 2),
#  ('"b".frente.', 3),
#  ('"b".gran', 1),
#  ('"b".impecable', 1),
#  ('"b".lepore', 13),
#  ('"b".medios', 2),
#  ('"b".pb:', 2),
#  ('"b".pleno', 1),
#  ('"b".sucursal', 2),
#  ('"b".varias', 1),
#  ('"b".venta', 4),
#  ('"b".y', 1),
#  ('"b":', 16),
#  ('"b";', 1),
#  ('"b"bajas', 4),
#  ('"b"consultas', 1),
#  ('"b"cons\xc3\x9altenosjumo', 1),
#  ('"b"disponible', 3),
#  ('"b"el', 1),
#  ('"b"en', 2),
#  ('"b"innumerables', 1),
#  ('"b"no', 1),
#  ('"b"n\xc2\xba', 4),
#  ('"b"opci\xc3\x83n', 1),
#  ('"b"si', 5),
#  ('"b"solo', 4),
#  ('"b"tercer', 1),
#  ('"b"y', 1),
#  ('"bachas', 1),
#  ('"bahia"', 1),
#  ('"bahia"estar-comedor.', 2),
#  ('"bajas', 5),
#  ('"bajo', 4),
#  ('"balcones', 1),
#  ('"barandas', 1),
#  ('"barbarita".', 1),
#  ('"barcelona', 10),
#  ('"baron', 1),
#  ('"barracas', 1),
#  ('"barrancas', 8),
#  ('"barrio', 30),
#  ('"barrio"', 12),
#  ('"barrio".', 1),
#  ('"barrio".**las', 2),
#  ('"barrio"y', 6),
#  ('"barrios"', 1),
#  ('"barriot",', 1),
#  ('"base",', 1),
#  ('"basement")', 1),
#  ('"baulera"', 1),
#  ('"baxi",', 8),
#  ('"baxi",la', 1),
#  ('"baxi".', 4),
#  ('"ba\xc3\x83\xc2\xb1o', 1),
#  ('"ba\xc3\xb1oslas', 1),
#  ('"be"', 11),
#  ('"beiro"', 1),
#  ('"belgrano', 15),
#  ('"belgrano"', 2),
#  ('"bella', 1),
#  ('"bermudas"', 1),
#  ('"bgh', 2),
#  ('"bienvenidos', 5),
#  ('"black', 5),
#  ('"black-out".puertas', 27),
#  ('"blindada"calefacci\xc3\xb3n', 1),
#  ('"blum",', 1),
#  ('"bo.', 2),
#  ('"boating', 1),
#  ('"boca', 1),
#  ('"boedo"', 1),
#  ('"boleto', 2),
#  ('"bosca",', 1),
#  ('"bosque', 1),
#  ('"botanic', 1),
#  ('"bouchard', 2),
#  ('"boulevard', 6),
#  ('"boulevares"muy', 2),
#  ('"bow', 1),
#  ('"boyaca"', 2),
#  ('"britanico"', 3),
#  ('"bs.as.', 1),
#  ('"buen', 2),
#  ('"buena', 1),
#  ('"buenos', 4),
#  ('"bulnes",', 1),
#  ('"bulnes".', 1),
#  ('"b\xe2\x80\x9d', 1),
#  ('"c")', 1),
#  ('"c"):', 1),
#  ('"c",', 61),
#  ('"c"----------------------u$s', 7),
#  ('"c".', 39),
#  ('"c".antiguo', 2),
#  ('"c".colectivos:', 1),
#  ('"c".la', 1),
#  ('"c".muy', 2),
#  ('"c".pb:', 3),
#  ('"c".todas', 4),
#  ('"c".ubicado', 1),
#  ('"c":', 2),
#  ('"c":88,05', 3),
#  ('"c";', 2),
#  ('"c"al', 1),
#  ('"c"cochera', 1),
#  ('"c"con', 2),
#  ('"c"consultas', 1),
#  ('"c"contrafrente', 15),
#  ('"c"cuarto', 1),
#  ('"c"en', 1),
#  ('"c"n\xc2\xba', 6),
#  ('"c"para', 3),
#  ('"c-f"superficie', 1),
#  ('"caba").-', 1),
#  ('"caballito', 1),
#  ('"cabildo"', 2),
#  ('"caldaia"', 2),
#  ...]

# %% [markdown]
# ### Hay que borrar todos los signos especiales y todos los numeros
