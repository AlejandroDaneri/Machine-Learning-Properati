# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
properati = pd.read_csv('datos/caba_para_mapa.csv',index_col=0,error_bad_lines=False)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:97% !important; }</style>"))
# Out:
# <style>.container { width:97% !important; }</style>

# %%
bins=[0,500,1000,1500,2000,2500,3000]
labels=['Very Low','Low','Medium','High','Very High','Only Carlos Slim can buy this fucking shit']

# %%
properati['categories_by_price']=pd.cut(properati['price_usd_per_m2'],bins,labels=labels)
properati['price_range']=pd.cut(properati['price_usd_per_m2'],bins)

# %%
pd.value_counts(properati['categories_by_price'])
# Out:
# Very High                                     13521
# High                                          10465
# Only Carlos Slim can buy this fucking shit     9087
# Medium                                         4834
# Low                                            1891
# Very Low                                        488
# Name: categories_by_price, dtype: int64

# %%
properati.head()
# Out:
#            property_type        place_name       state_name  \
# created_on
# 2015-07-01     apartment           Palermo  Capital Federal
# 2015-07-01     apartment  Villa del Parque  Capital Federal
# 2015-07-01     apartment  Villa del Parque  Capital Federal
# 2015-07-01     apartment          Barracas  Capital Federal
# 2015-07-01         house          Barracas  Capital Federal
#
#                                                lat-lon        lat        lon  \
# created_on
# 2015-07-01  (-34.574594426799997, -58.419254851700003) -34.574594 -58.419255
# 2015-07-01  (-34.610611015700002, -58.479590288599994) -34.610611 -58.479590
# 2015-07-01  (-34.610611015700002, -58.479590288599994) -34.610611 -58.479590
# 2015-07-01  (-34.639085999999999, -58.369346999999998) -34.639086 -58.369347
# 2015-07-01       (-34.6781214564, -58.392211397499999) -34.678121 -58.392211
#
#                price currency  price_aprox_local_currency  price_aprox_usd  \
# created_on
# 2015-07-01   71000.0      USD                   1252759.5          71000.0
# 2015-07-01   96000.0      USD                   1693872.0          96000.0
# 2015-07-01   86000.0      USD                   1517427.0          86000.0
# 2015-07-01  165000.0      USD                   2911342.5         165000.0
# 2015-07-01   85000.0      USD                   1499782.5          85000.0
#
#                 ...                                           properati_url  \
# created_on      ...
# 2015-07-01      ...       http://www.properati.com.ar/rlpn_venta_departa...
# 2015-07-01      ...       http://www.properati.com.ar/rls7_venta_departa...
# 2015-07-01      ...       http://www.properati.com.ar/rls8_venta_departa...
# 2015-07-01      ...       http://www.properati.com.ar/rlxf_venta_departa...
# 2015-07-01      ...       http://www.properati.com.ar/rm64_venta_casa_av...
#
#                                                   description  \
# created_on
# 2015-07-01  VENTA DEPARTAMENTO DE 1 AMBIENTE CON PATIO EN ...
# 2015-07-01  ESPECTACULAR DOS AMBIENTES DE 47M2 TOTALES EN ...
# 2015-07-01  ESPECTACULAR DOS AMBIENTES DE 47M2 TOTALES EN ...
# 2015-07-01  MOLINA CIUDADEX - ALPARGATASIMPACTANTE EDIFICI...
# 2015-07-01  CODIGO: 2912-PH1006V ubicado en: Peru 2100 -  ...
#
#                                             title  dist_a_subte  dist_a_tren  \
# created_on
# 2015-07-01                Departamento en Palermo           2.7          4.2
# 2015-07-01          SAN BLAS 2700 6º-  A ESTRENAR           7.3          8.0
# 2015-07-01          SAN BLAS 2700 4º-  A ESTRENAR           7.3          8.0
# 2015-07-01                  DEPARTAMENTO EN VENTA           5.8         12.7
# 2015-07-01  Duplex en PH - Avellaneda - Excelente           9.3         15.7
#
#             dist_a_univ  dist_a_villa dist_a_zona_anegada categories_by_price  \
# created_on
# 2015-07-01          4.1           8.6                 8.0           Very High
# 2015-07-01          8.9           8.8                 2.8           Very High
# 2015-07-01          8.9           8.8                 2.8                High
# 2015-07-01          4.9           2.7                13.2                High
# 2015-07-01          9.1           3.2                13.8              Medium
#
#              price_range
# created_on
# 2015-07-01  (2000, 2500]
# 2015-07-01  (2000, 2500]
# 2015-07-01  (1500, 2000]
# 2015-07-01  (1500, 2000]
# 2015-07-01  (1000, 1500]
#
# [5 rows x 27 columns]
