# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:97% !important; }</style>"))

import jupyternotify
ip = get_ipython()
ip.register_magics(jupyternotify.JupyterNotifyMagics)

import scoring as score # para hacer los reportes de puntajes
from time import time

properati = pd.read_csv('datos/properati_final.csv',error_bad_lines=False)
# Out:
# <style>.container { width:97% !important; }</style>

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=n_features, stop_words="english")

# %%
properati.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136352 entries, 0 to 136355
# Data columns (total 23 columns):
# created_on                    136352 non-null object
# property_type                 136352 non-null object
# place_name                    136352 non-null object
# state_name                    136352 non-null object
# lat-lon                       136352 non-null object
# lat                           96342 non-null float64
# lon                           96342 non-null float64
# price                         136352 non-null float64
# currency                      136352 non-null object
# price_aprox_local_currency    136352 non-null float64
# price_aprox_usd               136352 non-null float64
# surface_total_in_m2           136352 non-null float64
# surface_covered_in_m2         136352 non-null float64
# price_usd_per_m2              136352 non-null float64
# price_per_m2                  136352 non-null float64
# ...

# %%
properati=properati.dropna(subset=["description"])
tfidf = tfidf_vectorizer.fit_transform(properati["description"])

# %%
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)
# Out:
# Topic #0: olivos igual interiores tipo cumplimiento reales posee independientes ver terreno ley tiene próximo quincho crespo venecitas valor pesos vista áreas
# Topic #1: vidrios termotanque uno funcionales mesadas fv vista independientes ubicación justo legal separada cucicba ubicada ofrece varias autos pvc hace agua
# Topic #2: estrenar cucicba tradicional portero independientes reales baja supeditada realizar primera luminosa plata para horno olivos bauleras categoría martín tv lotes
# Topic #3: termotanque independientes interiores hermosa legal igual venecitas misma revestida depto izrastzoff cucicba balcon terrazas desarrollo privado parte visita frentes frio
# Topic #4: tipo misma 08 área radiadores mã mueble 200 17 16 exclusivo 2do verificación está tercer mat colectivo 100 15 pasos
# Topic #5: ubicación monocomando chalet excelente misma títulos construcción subte hacer te optativas próximo habitacion residencial placards comparten entrega juegos ubicada propiedades
# ...

# %%
tfidf_vectorizer.stop_words_
# Out:
# {u'administradola',
#  u'principalescolectivos',
#  u'deparque',
#  u'bloqueos',
#  u'vanguardiagran',
#  u'55m2porch',
#  u'woods',
#  u'primarios',
#  u'prestadoras',
#  u'27\xba',
#  u'hipotecariolepore',
#  u'dixon37004373',
#  u'330m2',
#  u'ambosbao',
#  u'ac46545horacio',
#  u'parrillavarias',
#  u'5980',
#  u'44323514',
#  u'00estudio',
#  u'ciudadel',
#  u'ciudades',
#  u'wp0101',
#  u'categoriazona',
#  u'nuevounica',
#  u'p14307c\xf3digo',
#  u'complejoc\xe3',
#  u'1800seguridad',
#  u'ciudadex',
#  u'canel',
#  u'terazza',
#  u'65m2cochera',
#  u'ba\xf1olavadero',
#  u'retiroubicado',
#  u'climatizadapor',
#  u'excelenbte',
#  u'car102',
#  u'impecablemente',
#  u'monsenor',
#  u'250m2superficie',
#  u'parquizaci\xf3nlos',
#  u'dixon3901866',
#  u'luminosolugar',
#  u'105m\xb2muy',
#  u'enmarcados',
#  u'cocinamuebles',
#  u'wooden',
#  u'balc\xf3nsegundo',
#  u'flemig',
#  u'moderadas',
#  u'proyector',
#  u'minoristas',
#  u'sericio',
#  u'gabrielhermosa',
# ...
