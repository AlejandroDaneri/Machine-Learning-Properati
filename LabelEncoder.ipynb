# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
properati = pd.read_csv('datos/caba_para_mapa.csv',index_col=0,error_bad_lines=False)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:97% !important; }</style>"))
# Out:
# <style>.container { width:97% !important; }</style>

# %%
properati.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49955 entries, 2015-07-01 to 2017-08-01
# Data columns (total 25 columns):
# property_type                 49955 non-null object
# place_name                    49955 non-null object
# state_name                    49955 non-null object
# lat-lon                       49955 non-null object
# lat                           49955 non-null float64
# lon                           49955 non-null float64
# price                         49955 non-null float64
# currency                      49955 non-null object
# price_aprox_local_currency    49955 non-null float64
# price_aprox_usd               49955 non-null float64
# surface_total_in_m2           49955 non-null float64
# surface_covered_in_m2         48166 non-null float64
# price_usd_per_m2              49112 non-null float64
# price_per_m2                  49955 non-null float64
# floor                         6576 non-null float64
# rooms                         34521 non-null float64
# ...

# %%
from sklearn import preprocessing

le_tipo = preprocessing.LabelEncoder()
tipos_prop=properati['property_type']
le_tipo.fit(tipos_prop)
properati['property_type'] = le_tipo.transform(tipos_prop)
print list(le_tipo.inverse_transform([0,1,2,3]))

le_region = preprocessing.LabelEncoder() 
regiones=properati['state_name']
le_region.fit(regiones)
properati['state_name'] = le_region.transform(regiones)

le_barrio = preprocessing.LabelEncoder()
barrios=properati['place_name']
le_barrio.fit(barrios)
properati['place_name'] = le_barrio.transform(barrios)
# Out:
# ['PH', 'apartment', 'house', 'store']

# %%
properati
# Out:
#             property_type  place_name  state_name  \
# created_on
# 2015-07-01              1          28           0
# 2015-07-01              1          62           0
# 2015-07-01              1          62           0
# 2015-07-01              1           4           0
# 2015-07-01              2           4           0
# 2015-07-02              1          16           0
# 2015-07-02              1           6           0
# 2015-07-03              1          50           0
# 2015-07-03              1          50           0
# 2015-07-03              1          50           0
# 2015-07-03              2          33           0
# 2015-07-03              1          19           0
# 2015-07-03              1          37           0
# 2015-07-03              1          37           0
# 2015-07-03              1          37           0
# 2015-07-03              1          37           0
# 2015-07-03              1          37           0
# ...

# %%
print list(le_tipo.inverse_transform([0,1,2,3]))
# Out:
# ['PH', 'apartment', 'house', 'store']

# %%
print list(le_region.inverse_transform([0])) #porque es solo CABA
# Out:
# ['Capital Federal']

# %%
print list(le_barrio.inverse_transform(range(0,20)))
# Out:
# ['Abasto', 'Agronom\xc3\xada', 'Almagro', 'Balvanera', 'Barracas', 'Barrio Norte', 'Belgrano', 'Boca', 'Boedo', 'Caballito', 'Capital Federal', 'Catalinas', 'Centro / Microcentro', 'Chacarita', 'Coghlan', 'Colegiales', 'Congreso', 'Constituci\xc3\xb3n', 'Distrito de las Artes', 'Flores']

# %%
#quiero buscar las propiedades que esten en Flores
properati= properati.loc[properati['place_name'] == le_barrio.transform(['Flores'])[0]] #porque devuelve un array

# %%
properati
# Out:
#             property_type  place_name  state_name  \
# created_on
# 2015-07-03              1          19           0
# 2015-07-12              1          19           0
# 2015-07-24              1          19           0
# 2015-08-19              2          19           0
# 2015-08-21              1          19           0
# 2015-08-31              1          19           0
# 2015-09-01              0          19           0
# 2015-09-02              1          19           0
# 2015-09-02              1          19           0
# 2015-09-02              1          19           0
# 2015-09-02              1          19           0
# 2015-09-02              1          19           0
# 2015-09-02              1          19           0
# 2015-09-02              1          19           0
# 2015-09-02              1          19           0
# 2015-09-02              1          19           0
# 2015-09-23              1          19           0
# ...
